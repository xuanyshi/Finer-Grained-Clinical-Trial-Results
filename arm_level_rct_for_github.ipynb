# %% [markdown]
# <a href="https://colab.research.google.com/github/xuanyshi/clinical-trials-finer-grained-representation/blob/main/arm_level_rct_for_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install & Import

# %%
# !pip install ipython-autotime
# !pip install joblib
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.19.0
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.3.2)

# %%
import codecs
import xml.etree.ElementTree as ET
import sys
import csv
import pandas as pd
import numpy as np
import os
import json
import ast
import difflib
import zipfile
import ast
from collections import Counter
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from ast import literal_eval
import re
import scipy.stats as stats
from tqdm import tqdm
from datetime import datetime
import pytz
import torch
import numpy as np
import joblib
from joblib import Parallel, delayed
from scipy.spatial.distance import cdist

from sklearn.metrics.pairwise import cosine_similarity
import torch

# %load_ext autotime
# Out:
# time: 344 µs (started: 2023-09-30 01:13:48 +00:00)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# time: 32.6 s (started: 2023-09-30 01:13:48 +00:00)

# %%
tqdm.pandas()
beijing_tz = pytz.timezone('Asia/Shanghai')  # Beijing is in the 'Asia/Shanghai' timezone
beijing_time = datetime.now(beijing_tz)
# Out:
# time: 25.9 ms (started: 2023-09-07 00:10:00 +00:00)

# %% [markdown]
# # Read data

# %%
df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/mti_results/mesh_outcome_df_0628.pickle')
df = df.rename(columns={'comparator_type':'comparator','comparator':'comparator_type'})

df['intervention'] =df['intervention'].apply(lambda x:ast.literal_eval(x))
df['intervention_type'] =df['intervention_type'].apply(lambda x:ast.literal_eval(x))
df['comparator'] =df['comparator'].apply(lambda x:ast.literal_eval(x))
df['comparator_type'] =df['comparator_type'].apply(lambda x:ast.literal_eval(x))
df['groups'] =df['groups'].apply(lambda x:ast.literal_eval(x))
df['intervention_mesh'] =df['intervention_mesh'].apply(lambda x:ast.literal_eval(x))

df['intervention_dict'] = df.apply(lambda row: [{k: v} for k, v in zip(row['intervention'], row['intervention_type'])], axis=1)
df['comparator_dict'] = df.apply(lambda row: [{k: v} for k, v in zip(row['comparator'], row['comparator_type'])], axis=1)

print(df.shape)
print(df['NCT_id'].nunique())
# Out:
# (222361, 42)
# 18720
# time: 14.7 s (started: 2023-08-09 02:06:57 +00:00)

# %%
df = df[df['groups'].str.len()==2]
print(df.shape)
print(df['NCT_id'].nunique())
# Out:
# (191441, 42)
# 15742
# time: 295 ms (started: 2023-08-09 02:07:12 +00:00)

# %%
df[['intervention','intervention_dict','comparator','comparator_dict','groups']].sample(5)
# Out:
#                                         intervention  \
# 155069                          [Danirixin, Placebo]
# 182862                       [Fezolinetant, Placebo]
# 37601   [Relugolix, Estradiol/norethindrone acetate]
# 157682                            [Iota-Carrageenan]
# 125031                             [Novel Ibuprofen]
#
#                                         intervention_dict  \
# 155069       [{'Danirixin': 'Drug'}, {'Placebo': 'Drug'}]
# 182862    [{'Fezolinetant': 'Drug'}, {'Placebo': 'Drug'}]
# 37601   [{'Relugolix': 'Drug'}, {'Estradiol/norethindr...
# 157682                   [{'Iota-Carrageenan': 'Device'}]
# 125031                      [{'Novel Ibuprofen': 'Drug'}]
#
#                                                comparator  \
# 155069                                                 []
# 182862                                                 []
# 37601   [Relugolix placebo, Estradiol/norethindrone ac...
# 157682                                          [Placebo]
# 125031                      [Standard Ibuprofen, Placebo]
#
#                                           comparator_dict  \
# 155069                                                 []
# 182862                                                 []
# 37601   [{'Relugolix placebo': 'Drug'}, {'Estradiol/no...
# 157682                            [{'Placebo': 'Device'}]
# 125031  [{'Standard Ibuprofen': 'Drug'}, {'Placebo': '...
#
#                                                    groups
# 155069                               [Placebo, DNX 75 mg]
# 182862                  [Placebo, Fezolinetant 15 mg BID]
# 37601   [Relugolix Plus E2/NETA (Group A), Placebo (Gr...
# 157682                              [Placebo, Bisolviral]
# 125031          [Ibuprofen Sodium, Ibuprofen (Motrin IB)]
# time: 78.9 ms (started: 2023-08-09 02:07:12 +00:00)

# %%
print(df.columns)
print(df.shape)

# %%
df_new = df[df.apply(lambda row: all(len(row[col]) > 0 for col in ['intervention', 'comparator', 'groups']), axis=1)]
print(df_new.shape)
print(df_new['NCT_id'].nunique())
# Out:
# (119968, 42)
# 8665
# time: 1.67 s (started: 2023-08-09 02:07:16 +00:00)

# %%
full_df = df_new
sample_df = df_new.sample(50)
#[['NCT_id','intervention_mesh','all_inters','intervention','comparator','groups','outcome_title','label']].to_excel(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/mti_results/df_new_arm.xlsx')
# Out:
# time: 5.44 ms (started: 2023-08-08 00:52:31 +00:00)

# %% [markdown]
# # biobert classification (inter vs compa)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# time: 4.02 s (started: 2023-08-10 01:54:19 +00:00)

# %%
from transformers import AutoTokenizer, AutoModel
import torch
from scipy.spatial.distance import cosine

# Load the BioBERT model and tokenizer
model_name = "dmis-lab/biobert-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = model.to('cuda')
# Out:
# time: 12.3 s (started: 2023-08-10 03:20:11 +00:00)

# %%
torch.cuda.is_available()
# Out:
# True
# time: 2.81 ms (started: 2023-08-10 02:24:13 +00:00)

# %%
# Function to generate sentence embedding
def get_sentence_embedding(sentence):
    device = 'cuda'
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True).to(device)
    outputs = model(**inputs)
    sentence_embedding = torch.mean(outputs.last_hidden_state[0], dim=0)
    return sentence_embedding

# Generate embeddings for two sentences
sentence1 = "covid-19"
sentence2 = "coronavirus"
embedding1 = get_sentence_embedding(sentence1)
embedding2 = get_sentence_embedding(sentence2)

# Compute the cosine similarity of the two embeddings
similarity = 1 - cosine(embedding1.cpu().detach().numpy(), embedding2.cpu().detach().numpy())
print(f"The similarity between the two sentences is: {similarity}")
# Out:
# The similarity between the two sentences is: 0.8009061217308044
# time: 515 ms (started: 2023-08-08 00:56:53 +00:00)

# %%
#test
from scipy.spatial.distance import cdist

def get_batch_embeddings(sentences):
    device = 'cuda'  # define your device here
    inputs = tokenizer(sentences, return_tensors="pt", padding=True, truncation=True).to(device)
    outputs = model(**inputs)
    embeddings = torch.mean(outputs.last_hidden_state, dim=1).cpu().detach().numpy()
    return embeddings

def label_groups_with_embeddings_dict(row):
    groups = row["groups"]
    intervention_dicts = row["intervention_dict"]
    comparator_dicts = row["comparator_dict"]

    group_embeddings = get_batch_embeddings(groups)

    intervention_group = None
    intervention_value = None
    comparator_group = None
    comparator_value = None

    max_intervention_similarity = 0
    max_comparator_similarity = 0

    for group, group_embedding in zip(groups, group_embeddings):
        for intervention_dict in intervention_dicts:
            for key, value in intervention_dict.items():
                key_embedding = get_batch_embeddings([key])
                intervention_similarity = 1 - cdist(group_embedding[np.newaxis], key_embedding, 'cosine')[0][0]

                if intervention_similarity > max_intervention_similarity:
                    max_intervention_similarity = intervention_similarity
                    intervention_group = group
                    intervention_value = value

        for comparator_dict in comparator_dicts:
            for key, value in comparator_dict.items():
                key_embedding = get_batch_embeddings([key])
                comparator_similarity = 1 - cdist(group_embedding[np.newaxis], key_embedding, 'cosine')[0][0]

                if comparator_similarity > max_comparator_similarity:
                    max_comparator_similarity = comparator_similarity
                    comparator_group = group
                    comparator_value = value

    return pd.Series([
        intervention_group, intervention_value, max_intervention_similarity,
        comparator_group, comparator_value, max_comparator_similarity
    ])
# Out:
# time: 1.04 ms (started: 2023-08-08 00:56:57 +00:00)

# %%
# from scipy.spatial.distance import cdist

# def get_batch_embeddings(sentences):
#     device = 'cuda'  # define your device here
#     inputs = tokenizer(sentences, return_tensors="pt", padding=True, truncation=True).to(device)
#     outputs = model(**inputs)
#     embeddings = torch.mean(outputs.last_hidden_state, dim=1).cpu().detach().numpy()
#     return embeddings

# def label_groups_with_embeddings_dict(row):
#     groups = row["groups"]
#     intervention_dicts = row["intervention_dict"]  # If this is already a list of dictionaries
#     comparator_dicts = row["comparator_dict"]  # Make sure this column exists

#     group_embeddings = get_batch_embeddings(groups)

#     intervention_group = None
#     intervention_value = None
#     comparator_group = None
#     comparator_value = None

#     max_intervention_similarity = 0
#     max_comparator_similarity = 0

#     for group, group_embedding in zip(groups, group_embeddings):
#         for intervention_dict in intervention_dicts:
#             for key, value in intervention_dict.items():
#                 key_embedding = get_batch_embeddings([key])
#                 intervention_similarity = 1 - cdist(group_embedding[np.newaxis], key_embedding, 'cosine')

#                 if intervention_similarity >= 0.8 and intervention_similarity > max_intervention_similarity:
#                     max_intervention_similarity = intervention_similarity
#                     intervention_group = group
#                     intervention_value = value  # store the value, not the key

#         for comparator_dict in comparator_dicts:
#             for key, value in comparator_dict.items():
#                 key_embedding = get_batch_embeddings([key])
#                 comparator_similarity = 1 - cdist(group_embedding[np.newaxis], key_embedding, 'cosine')

#                 if comparator_similarity >= 0.8 and comparator_similarity > max_comparator_similarity:
#                     max_comparator_similarity = comparator_similarity
#                     comparator_group = group
#                     comparator_value = value  # store the value, not the key

#     return pd.Series([intervention_group, intervention_value, comparator_group, comparator_value])
# Out:
# time: 1.93 ms (started: 2023-07-27 14:10:03 +00:00)

# %% [markdown]
# ### test

# %%
import subprocess as sp
import os

def get_gpu_memory():
    command = "nvidia-smi --query-gpu=memory.free --format=csv"
    memory_free_info = sp.check_output(command.split()).decode('ascii').split('\n')[:-1][1:]
    memory_free_values = [int(x.split()[0]) for i, x in enumerate(memory_free_info)]
    return memory_free_values

get_gpu_memory()
# Out:
# [14156]
# time: 36.8 ms (started: 2023-08-09 13:20:19 +00:00)

# %%
# !nvidia-smi
# Out:
# Wed Aug  9 13:19:50 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0    30W /  70W |    945MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# time: 107 ms (started: 2023-08-09 13:19:50 +00:00)

# %%
sample_sample = df_new.sample(200,random_state=2023)
sample_sample.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/sample_sample.csv')
# Out:
# time: 820 ms (started: 2023-08-08 00:57:12 +00:00)

# %%
print(sample_sample.shape)

new_columns = ["intervention_group", "intervention_value", "intervention_similarity",
               "comparator_group", "comparator_value", "comparator_similarity"]

sample_sample[new_columns] = sample_sample.progress_apply(label_groups_with_embeddings_dict, axis=1)

sample_sample.dropna(subset=['intervention_group', 'comparator_group'], inplace=True)
print(sample_sample.shape)
sample_sample.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_sample.csv')

sample_sample[["groups","intervention_group", "intervention_value", "comparator_group", "comparator_value"]].sample(5)
# Out:
# (200, 42)
# 100%|██████████| 200/200 [00:21<00:00,  9.18it/s]
# (200, 48)
#                                                    groups  \
# 166067  [QVM149 150/50/80 µg o.d., QMF149 150/160 µg o...
# 59512                               [Placebo, ZOMIG 5 mg]
# 181206                     [Placebo, Nemolizumab (90 mg)]
# 86445                                  [AZD7442, Placebo]
# 73706                         [PRM-151 10 mg/kg, Placebo]
#
#               intervention_group intervention_value        comparator_group  \
# 166067  QVM149 150/50/80 µg o.d.               Drug  QMF149 150/160 µg o.d.
# 59512                 ZOMIG 5 mg               Drug                 Placebo
# 181206       Nemolizumab (90 mg)               Drug                 Placebo
# 86445                    AZD7442               Drug                 Placebo
# 73706           PRM-151 10 mg/kg         Biological                 Placebo
#
#        comparator_value
# 166067             Drug
# 59512              Drug
# 181206             Drug
# 86445              Drug
# 73706             Other
# time: 22.4 s (started: 2023-08-08 00:57:19 +00:00)

# %% [markdown]
# ### not test

# %%
beijing_time = datetime.now(beijing_tz)
print(beijing_time)

print(full_df.shape)

new_columns = ["intervention_group", "intervention_value", "intervention_similarity",
               "comparator_group", "comparator_value", "comparator_similarity"]

full_df[new_columns] = full_df.progress_apply(label_groups_with_embeddings_dict, axis=1)

#full_df[["intervention_group", "intervention_value", "comparator_group", "comparator_value"]] = full_df.progress_apply(label_groups_with_embeddings_dict, axis=1)
full_df.dropna(subset=['intervention_group', 'comparator_group'], inplace=True)

print(full_df.shape)

full_df.to_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
full_df.to_json(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.json')
full_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.csv')
# Out:
# 2023-08-07 22:49:01.585081+08:00
# (119968, 48)
# 100%|██████████| 119968/119968 [3:40:29<00:00,  9.07it/s]
# <ipython-input-32-5f5e20633b82>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df[new_columns] = full_df.progress_apply(label_groups_with_embeddings_dict, axis=1)
# <ipython-input-32-5f5e20633b82>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df.dropna(subset=['intervention_group', 'comparator_group'], inplace=True)
# (119968, 48)
# time: 3h 40min 38s (started: 2023-08-07 14:49:01 +00:00)

# %% [markdown]
# #KG

# %%
# kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df.pickle')
# print(kg_df.shape)
# print(kg_df['NCT_id'].nunique())

kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)
print(kg_df.shape)
print(kg_df['NCT_ID'].nunique())
# Out:
# (119968, 48)
# 8665
# time: 1.59 s (started: 2023-08-11 03:19:50 +00:00)

# %%
kg_df_sample = kg_df.sample(20,random_state=2023)
kg_df_sample = kg_df[kg_df['NCT_ID'].isin(kg_df_sample['NCT_ID'].unique())]
print(kg_df_sample.shape)
kg_df_sample.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/kg_df_sample.csv')

kg_df.sample(5,random_state=2023)[["groups","intervention",'comparator',"intervention_group", "intervention_value", "intervention_similarity",
               "comparator_group", "comparator_value", "comparator_similarity"]]
# Out:
# (1541, 48)
#                                                    groups  \
# 159708                      [Placebo, GSK2269557 1000 µg]
# 41891                       [PF-04965842 200 mg, Placebo]
# 26247                [Placebo, Bococizumab (PF-04950615)]
# 126213  [Integrated Study (Main + Japan Sub-study): Pl...
# 208367  [PF-04937319 Once-Daily (300 mg), Sitagliptin ...
#
#                                             intervention  \
# 159708                                      [GSK2269557]
# 41891           [PF-04965842 100 mg, PF-04965842 200 mg]
# 26247                        [bococizumab (PF-04950615)]
# 126213                          [Adalimumab, Prednisone]
# 208367  [PF-04937319 once-daily, PF-04937319 split-dose]
#
#                       comparator  \
# 159708                 [Placebo]
# 41891                  [Placebo]
# 26247                  [Placebo]
# 126213                 [Placebo]
# 208367  [Sitagliptin once-daily]
#
#                                        intervention_group intervention_value  \
# 159708                                 GSK2269557 1000 µg               Drug
# 41891                                  PF-04965842 200 mg               Drug
# 26247                           Bococizumab (PF-04950615)               Drug
# 126213  Integrated Study (Main + Japan Sub-study): Ada...               Drug
# 208367                    PF-04937319 Once-Daily (300 mg)               Drug
#
#         intervention_similarity  \
# 159708                 0.921315
# 41891                  1.000000
# 26247                  0.963027
# 126213                 0.826469
# 208367                 0.961127
#
#                                          comparator_group comparator_value  \
# 159708                                            Placebo             Drug
# 41891                                             Placebo             Drug
# 26247                                             Placebo             Drug
# 126213  Integrated Study (Main + Japan Sub-study): Pla...             Drug
# 208367                                 Sitagliptin 100 mg             Drug
#
#         comparator_similarity
# 159708               0.886400
# 41891                0.894706
# 26247                0.864217
# 126213               0.745709
# 208367               0.919221
# time: 399 ms (started: 2023-08-11 03:19:57 +00:00)

# %% [markdown]
# # ADE

# %%
files = os.listdir(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/og_files')
# Out:
# time: 7.7 ms (started: 2023-08-11 02:19:18 +00:00)

# %%
file_list = []
for file in files:
  df_ade = pd.read_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/og_files/{file}')
  print(df_ade.shape)
  file_list.append(df_ade)

df_ade = pd.concat(file_list).drop(columns=['Unnamed: 0'])
print(df_ade.shape)
print(df_ade['NCT_ID'].nunique())
# Out:
# (305686, 11)
# (269295, 11)
# (623090, 11)
# (612090, 11)
# (1810161, 10)
# 18508
# time: 5.03 s (started: 2023-08-11 02:19:18 +00:00)

# %%
df_ade_sample = df_ade[df_ade['NCT_ID'].isin(kg_df_sample['NCT_id'].unique())]
print(df_ade_sample.shape)
df_ade_sample.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/df_ade_sample.csv')
# Out:
# (3067, 10)
# time: 444 ms (started: 2023-08-11 02:19:23 +00:00)

# %%
df_ade.sample(5)
# Out:
#              NCT_ID                           arm_title  \
# 168078  NCT03434379  Atezolizumab + Bevacizumab - China
# 181006  NCT00598273            Peginesatide 0.025 mg/kg
# 64033   NCT02229851            Somapacitan - Main Phase
# 50674   NCT02503202              V920 Consistency Lot C
# 441506  NCT01599650           Ranibizumab 0.5mg + Laser
#
#                        sub_title  \
# 168078       Varices oesophageal
# 181006  Cerebrovascular accident
# 64033              Cholangiogram
# 50674                  Back pain
# 441506           Cardiac failure
#
#                                                category serious/other  \
# 168078                       Gastrointestinal disorders       serious
# 181006                         Nervous system disorders       serious
# 64033                                    Investigations       serious
# 50674   Musculoskeletal and connective tissue disorders       serious
# 441506                                Cardiac disorders       serious
#
#         affected  at_risk  events   ratio edge_type
# 168078       0.0    132.0     0.0  0/.132
# 181006       0.0    161.0     0.0  0/.161
# 64033        0.0    120.0     0.0  0/.120
# 50674        0.0    263.0     0.0  0/.263
# 441506       1.0    183.0     1.0  1/.183    has_ae
# time: 104 ms (started: 2023-08-11 02:19:24 +00:00)

# %% [markdown]
# # Matching ADE and KG

# %% [markdown]
# ## method 1

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer, BertModel
import torch
from tqdm import tqdm


# Rename the 'NCT_id' column in kg_df_sample to match with 'NCT_ID' in df_ade_sample
kg_df_sample = kg_df_sample.copy(deep=True)
kg_df_sample.rename(columns={'NCT_id': 'NCT_ID'}, inplace=True)

# only keep ADE with valid affected number
df_ade_sample = df_ade_sample[df_ade_sample['affected']!=0]

# Merge the dataframes based on the matching criteria
matched_rows = pd.merge(df_ade_sample, kg_df_sample,
                        how='left',
                        left_on=['NCT_ID', 'arm_title'],
                        right_on=['NCT_ID', 'intervention_group'])

# Identify unmatched arm_titles (those with NaN in intervention_group column)
unmatched_rows = matched_rows[matched_rows['intervention_group'].isna()]

# Function to calculate embeddings
def calculate_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    inputs = {key: tensor.to(device) for key, tensor in inputs.items()}  # Move inputs to GPU if available
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).cpu().numpy()  # Move the result back to CPU


# Create a list to store the result rows
result_rows = []

# Loop through each unique NCT_ID
for nct_id in tqdm(df_ade_sample['NCT_ID'].unique()):
    study_rows = df_ade_sample[df_ade_sample['NCT_ID'] == nct_id]
    kg_study_rows = kg_df_sample[kg_df_sample['NCT_ID'] == nct_id]

    # Get unique intervention and comparator groups
    unique_intervention_groups = kg_study_rows['intervention_group'].unique()
    unique_comparator_groups = kg_study_rows['comparator_group'].unique()

    # Loop through each arm_title within the study
    for _, row in study_rows.iterrows():
        arm_title = row['arm_title']
        matched_group = None
        similarity = None

        # Step 1: Match by intervention_group
        if arm_title in unique_intervention_groups:
            matched_group = arm_title

        # Step 2: Match by comparator_group (if no match in step 1)
        elif arm_title in unique_comparator_groups:
            matched_group = arm_title

        # Step 3: Apply BioBERT (if no match in steps 1 and 2)
        else:
            arm_title_embedding = calculate_embedding(arm_title)
            max_similarity = -1
            for group_type, unique_groups in [('intervention_group', unique_intervention_groups), ('comparator_group', unique_comparator_groups)]:
                for group in unique_groups:
                    group_embedding = calculate_embedding(group)
                    current_similarity = cosine_similarity(arm_title_embedding.reshape(1, -1), group_embedding.reshape(1, -1))[0][0]
                    if current_similarity > max_similarity:
                        max_similarity = current_similarity
                        matched_group = group
                        similarity = max_similarity

        # Append the result as a dictionary to the result_rows list
        result_rows.append({
            'NCT_ID': nct_id,
            'arm_title': arm_title,
            'matched_group': matched_group,
            'similarity': similarity
        })

# Convert the result_rows list to a DataFrame
final_results = pd.DataFrame(result_rows)

# Merge with the original DataFrame (if needed)
final_df = pd.merge(df_ade_sample, final_results, how='left', on=['NCT_ID', 'arm_title'])

# Replace 'path/to/df_ade_sample.csv' and 'path/to/kg_df_sample.csv' with the actual paths to your files
# Replace 'biobert-path' with the correct path to the BioBERT model
# Out:
# 100%|██████████| 14/14 [00:13<00:00,  1.04it/s]
# time: 13.6 s (started: 2023-08-09 13:26:44 +00:00)

# %%
test_df = final_df[['NCT_ID','arm_title','sub_title','affected','at_risk','ratio','matched_group','similarity']].drop_duplicates(subset=['NCT_ID','arm_title','sub_title'])
test_df = test_df[test_df['affected']!=0]
print(test_df.shape)
test_df.sample(10,random_state=20)
# Out:
# (1469, 8)
#              NCT_ID                                          arm_title  \
# 224793  NCT01975376                                            Placebo
# 47118   NCT01975376                                            Placebo
# 10281   NCT01212770  APR Exposure Period Up to 5 Years: Apremilast ...
# 280892  NCT01975376                          Bococizumab (PF-04950615)
# 53298   NCT01975376                                            Placebo
# 159903  NCT01975376                                            Placebo
# 532783  NCT03070782                                            Placebo
# 3804    NCT01236547             (Phase II) Pazopanib, Paclitaxel, IMRT
# 532445  NCT03084796                                        Treatment E
# 139303  NCT01975376                                            Placebo
#
#                                     sub_title  affected  at_risk    ratio  \
# 224793                      Confusional state       2.0   8374.0  2/.8374
# 47118                            Constipation       1.0   8374.0  1/.8374
# 10281                           Cholecystitis       1.0    242.0   1/.242
# 280892                   Haemorrhagic anaemia       2.0   8386.0  2/.8386
# 53298                            Haematemesis       1.0   8374.0  1/.8374
# 159903                               Bursitis       1.0   8374.0  1/.8374
# 532783  Gastrointestinal anastomotic stenosis       1.0     47.0    1/.47
# 3804                                Neck pain       1.0     36.0    1/.36
# 532445          Total, serious adverse events       1.0    121.0   1/.121
# 139303                     Subdural haematoma       4.0   8374.0  4/.8374
#
#                                  matched_group  similarity
# 224793                                 Placebo         NaN
# 47118                                  Placebo         NaN
# 10281                         Apremilast 30 mg    0.841438
# 280892               Bococizumab (PF-04950615)         NaN
# 53298                                  Placebo         NaN
# 159903                                 Placebo         NaN
# 532783                                 Placebo         NaN
# 3804    (Phase II) Pazopanib, Paclitaxel, IMRT         NaN
# 532445                             Treatment E         NaN
# 139303                                 Placebo         NaN
# time: 154 ms (started: 2023-08-09 13:27:07 +00:00)

# %% [markdown]
# ## method 2 batch process

# %%
kg_df_sample = kg_df.copy(deep=True)
df_ade_sample = df_ade[df_ade['affected']!=0].copy(deep=True)
kg_df_sample.rename(columns={'NCT_id': 'NCT_ID'}, inplace=True)
# Out:
# time: 247 ms (started: 2023-08-11 03:20:08 +00:00)

# %%
print(kg_df_sample.shape,df_ade_sample.shape,df_ade.shape)
# Out:
# (119968, 48) (804812, 10) (1810161, 10)
# time: 561 µs (started: 2023-08-11 03:20:12 +00:00)

# %%
print(df_ade['NCT_ID'].nunique(),df_ade_sample['NCT_ID'].nunique())
# Out:
# 18508 11729
# time: 152 ms (started: 2023-08-11 03:20:14 +00:00)

# %%
# Function to calculate embeddings for a batch of texts
def calculate_embeddings(texts):
    inputs = tokenizer(texts, return_tensors='pt', truncation=True, padding=True, max_length=512)
    inputs = {key: tensor.to(device) for key, tensor in inputs.items()}  # Move inputs to GPU if available
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).cpu().numpy()  # Move the result back to CPU

# Create a list to store the result rows
result_rows = []

# Loop through each unique NCT_ID
for nct_id in tqdm(df_ade_sample['NCT_ID'].unique()):
    study_rows = df_ade_sample[df_ade_sample['NCT_ID'] == nct_id]
    kg_study_rows = kg_df_sample[kg_df_sample['NCT_ID'] == nct_id]

    # Get unique intervention and comparator groups
    unique_groups = np.concatenate([kg_study_rows['intervention_group'].dropna().unique(),
                                    kg_study_rows['comparator_group'].dropna().unique()])
    unique_groups = [str(group) for group in unique_groups if str(group).strip()]  # Convert to a list of non-empty strings

    # Check if unique_groups is not empty
    if unique_groups:
        # Calculate embeddings for unique groups only once
        unique_group_embeddings = calculate_embeddings(unique_groups)
    else:
        continue  # Skip this NCT_ID if there are no valid unique groups

    # Dictionary to store matched groups for identical arm_titles
    arm_title_matched_groups = {}

    # Process arm titles in batches
    batch_size = 15  # Adjust based on available GPU memory
    for i in range(0, len(study_rows), batch_size):
        batch_arm_titles = study_rows['arm_title'].iloc[i:i+batch_size].tolist()

        # Calculate embeddings for the batch of arm titles
        arm_title_embeddings = calculate_embeddings(batch_arm_titles)

        # Process each arm title in the batch
        for arm_title, arm_title_embedding in zip(batch_arm_titles, arm_title_embeddings):
            # Check if this arm_title has already been matched
            if arm_title in arm_title_matched_groups:
                matched_group, similarity = arm_title_matched_groups[arm_title]
            else:
                matched_group = None
                similarity = None

                # Match by unique_groups
                if arm_title in unique_groups:
                    matched_group = arm_title
                else:
                    # Apply BioBERT
                    similarities = cosine_similarity(arm_title_embedding.reshape(1, -1), unique_group_embeddings)
                    max_similarity_idx = np.argmax(similarities)
                    matched_group = unique_groups[max_similarity_idx]
                    similarity = similarities[0, max_similarity_idx]

                # Store the matched group for identical arm_titles
                arm_title_matched_groups[arm_title] = (matched_group, similarity)

            # Append the result as a dictionary to the result_rows list
            result_rows.append({
                'NCT_ID': nct_id,
                'arm_title': arm_title,
                'matched_group': matched_group,
                'similarity': similarity
            })

# Convert the result_rows list to a DataFrame
final_results = pd.DataFrame(result_rows)
print(final_results.shape,df_ade_sample.shape)
# Out:
# 100%|██████████| 11729/11729 [21:50<00:00,  8.95it/s]
# (538311, 4) (804812, 10)
# time: 21min 50s (started: 2023-08-10 03:34:19 +00:00)

# %%
final_results.to_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/final_results.pickle')
# Out:
# time: 108 ms (started: 2023-08-10 03:57:58 +00:00)

# %%
final_results = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/final_results.pickle')
# Out:
# time: 97.5 ms (started: 2023-08-11 03:20:20 +00:00)

# %%
# Merge with the original DataFrame (if needed)

# chunk_size = 45000  # Adjust based on available memory
# final_df = pd.DataFrame()

# for i in tqdm(range(0, len(df_ade_sample), chunk_size)):
#     chunk = df_ade_sample.iloc[i:i + chunk_size]
#     merged_chunk = pd.merge(chunk, final_results, how='left', on=['NCT_ID', 'arm_title'])
#     final_df = pd.concat([final_df, merged_chunk])

# final_df = final_df.drop_duplicates()
# print(final_df.shape)
# Now final_df contains the merged data

final_df = pd.merge(df_ade_sample, final_results.drop_duplicates(), how='left', on=['NCT_ID', 'arm_title'])

# Replace 'path/to/df_ade_sample.csv' and 'path/to/kg_df_sample.csv' with the actual paths to your files
# Replace 'biobert-path' with the correct path to the BioBERT model
# Out:
# time: 469 ms (started: 2023-08-11 02:27:49 +00:00)

# %%
ade_result_matched_df = final_df.drop_duplicates(subset=['NCT_ID','arm_title','sub_title'])
print(ade_result_matched_df.shape)
ade_result_matched_df['matched_group'].fillna(ade_result_matched_df['arm_title'],inplace=True)
ade_result_matched_df.to_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
ade_result_matched_df.to_json(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.json')
ade_result_matched_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.csv')
# Out:
# (803052, 12)
# <ipython-input-65-2240fd3cea16>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ade_result_matched_df['matched_group'].fillna(ade_result_matched_df['arm_title'],inplace=True)
# time: 13.8 s (started: 2023-08-11 07:52:06 +00:00)

# %%
ade_result_matched_df = pd.read_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.csv')
# Out:
# time: 2.1 s (started: 2023-09-07 00:14:22 +00:00)

# %%
sample = ade_result_matched_df.sample(5,random_state=95)[['NCT_ID','arm_title','sub_title','category','serious/other','affected','at_risk','matched_group']]
sample.to_excel(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ade_sample.xlsx')
sample
# Out:
#              NCT_ID                              arm_title  \
# 386146  NCT00977080  Oral Paricalcitol in the Oral Stratum
# 544911  NCT02254278                           IMRT 5 Weeks
# 672578  NCT00509145                      Laquinimod 0.6 mg
# 701901  NCT00810199                  Tocilizumab + Placebo
# 580468  NCT02853331                              Sunitinib
#
#                             sub_title  \
# 386146                 Abdominal pain
# 544911                        Syncope
# 672578               Uterine prolapse
# 701901  Clostridium difficile colitis
# 580468          Hepatocellular injury
#
#                                         category serious/other  affected  \
# 386146                Gastrointestinal disorders       serious       1.0
# 544911                  Nervous system disorders       serious       1.0
# 672578  Reproductive system and breast disorders       serious       1.0
# 701901               Infections and infestations       serious       1.0
# 580468                   Hepatobiliary disorders       serious       1.0
#
#         at_risk                          matched_group
# 386146     72.0  Oral Paricalcitol in the Oral Stratum
# 544911    147.0                           IMRT 5 Weeks
# 672578    550.0                             Laquinimod
# 701901    276.0                  Tocilizumab + Placebo
# 580468    425.0                              Sunitinib
# time: 77.5 ms (started: 2023-09-07 00:18:18 +00:00)

# %% [markdown]
# # Matching ARM with Intervention_MeSH

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)
print(kg_df.shape)
print(kg_df['NCT_ID'].nunique())
# Out:
# (119968, 48)
# 8665
# time: 5.41 s (started: 2023-09-16 12:35:11 +00:00)

# %%
kg_df[['outcome_type']].value_counts()
# Out:
# outcome_type
# Secondary              92966
# Primary                23252
# Other Pre-specified     3452
# Post-Hoc                 298
# dtype: int64
# time: 22.2 ms (started: 2023-09-16 12:35:39 +00:00)

# %%
inter_group_mesh_rel = kg_df[kg_df['intervention_mesh'].str.len()==1][['intervention_group','intervention_mesh']]
print(inter_group_mesh_rel.shape)
inter_group_mesh_rel['intervention_mesh'] = inter_group_mesh_rel['intervention_mesh'].apply(lambda x:x[0])
inter_group_mesh_rel.drop_duplicates()
print(inter_group_mesh_rel.shape)
inter_group_mesh_rel['relation'] = 'is_a'

inter_group_mesh_rel.to_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')
inter_group_mesh_rel[['intervention_group','intervention_mesh','relation']].sample(5)
# Out:
# (49764, 2)
# (49764, 2)
#           intervention_group         intervention_mesh relation
# 12309             Duloxetine  Duloxetine Hydrochloride     is_a
# 144164         Brexpiprazole             Brexpiprazole     is_a
# 101254  Preladenant 1 mg BID                  Levodopa     is_a
# 14606       Ibuprofen Sodium                 Ibuprofen     is_a
# 8835          Tanezumab 5 mg                 Tanezumab     is_a
# time: 234 ms (started: 2023-08-29 08:10:26 +00:00)

# %% [markdown]
# # case : infliximab vs infections

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)

ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')
# Out:
# time: 5.73 s (started: 2023-09-15 08:11:40 +00:00)

# %% [markdown]
# ## check how many trials have both ae and efficacy

# %%
print(ade_result_matched_df.shape,ade_result_matched_df['NCT_ID'].nunique())
# Out:
# (803052, 12) 11729
# time: 54.4 ms (started: 2023-09-15 08:24:50 +00:00)

# %%
print(kg_df.shape,kg_df['NCT_ID'].nunique())
# Out:
# (119968, 48) 8665
# time: 16 ms (started: 2023-09-15 08:45:07 +00:00)

# %%
shared = list(set(ade_result_matched_df['NCT_ID'].unique()).intersection(set(kg_df['NCT_ID'].unique())))
print(len(shared))
# Out:
# 6429
# time: 60 ms (started: 2023-09-15 08:50:26 +00:00)

# %%
shared[:10]
# Out:
# ['NCT00838916',
#  'NCT00450216',
#  'NCT01154088',
#  'NCT03082196',
#  'NCT02413372',
#  'NCT00681564',
#  'NCT02117414',
#  'NCT02265744',
#  'NCT03036150',
#  'NCT02139644']
# time: 3.23 ms (started: 2023-09-15 08:52:36 +00:00)

# %%
print(ade_result_matched_df['category'].isnull().sum())
# Out:
# 0
# time: 43.7 ms (started: 2023-09-07 02:56:39 +00:00)

# %%
print(kg_df['intervention_group'].nunique())
print(kg_df['outcome_title'].nunique())
print(ade_result_matched_df['sub_title'].nunique())
print(ade_result_matched_df['category'].nunique())

print(kg_df.shape,ade_result_matched_df.shape)
# Out:
# 10364
# 41708
# 40408
# 28
# (119968, 48) (803052, 12)
# time: 213 ms (started: 2023-09-07 02:47:55 +00:00)

# %%
mesh_outcome_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/mti_results/mesh_outcome_df_0628.pickle')
print(mesh_outcome_df.shape,mesh_outcome_df.columns)
# Out:
# (222361, 40) Index(['NCT_id', 'study_type', 'completion_year', 'trial_phase',
#        'enrollment_num', 'allocation', 'Countries', 'funder_name',
#        'funder_type', 'condition_mesh', 'intervention_mesh', 'condition',
#        'age', 'all_inters', 'intervention_type', 'intervention',
#        'comparator_type', 'comparator', 'outcome_id', 'info', 'groups',
#        'outcome_type', 'outcome_title', 'p_value', 'method', 'method_desc',
#        'ci_percent', 'ci_n_sides', 'ci_lower_limit', 'ci_upper_limit',
#        'param_type', 'param_value', 'split_p', 'p_split', 'label',
#        'ci_lower_limit_clean', 'ci_upper_limit_clean', 'mesh_terms_mti',
#        'mapped_mesh_terms', 'tree_level_0'],
#       dtype='object')
# time: 622 ms (started: 2023-09-07 02:59:19 +00:00)

# %% [markdown]
# ## examples for group separation

# %%
print(kg_df.columns)
# Out:
# Index(['NCT_ID', 'study_type', 'completion_year', 'trial_phase',
#        'enrollment_num', 'allocation', 'Countries', 'funder_name',
#        'funder_type', 'condition_mesh', 'intervention_mesh', 'condition',
#        'age', 'all_inters', 'intervention_type', 'intervention', 'comparator',
#        'comparator_type', 'outcome_id', 'info', 'groups', 'outcome_type',
#        'outcome_title', 'p_value', 'method', 'method_desc', 'ci_percent',
#        'ci_n_sides', 'ci_lower_limit', 'ci_upper_limit', 'param_type',
#        'param_value', 'split_p', 'p_split', 'label', 'ci_lower_limit_clean',
#        'ci_upper_limit_clean', 'mesh_terms_mti', 'mapped_mesh_terms',
#        'tree_level_0', 'intervention_dict', 'comparator_dict',
#        'intervention_group', 'intervention_value', 'intervention_similarity',
#        'comparator_group', 'comparator_value', 'comparator_similarity'],
#       dtype='object')
# time: 872 µs (started: 2023-09-06 08:29:35 +00:00)

# %%
kg_df.sample(10,random_state=230)[['NCT_ID','groups','intervention','comparator','intervention_group','comparator_group']]
# Out:
#              NCT_ID                                             groups  \
# 150032  NCT01694849                             [GFT505 80mg, Placebo]
# 206348  NCT01529346                               [Ibuprofen, Placebo]
# 130501  NCT01227564                          [ACC 3 μg+QS-21, Placebo]
# 48001   NCT00402246                        [Remote Arm, In-Office Arm]
# 30618   NCT02421510                    [Placebo, Sotagliflozin 200 mg]
# 210754  NCT03077438  [Group 1: MenACYW Conjugate Vaccine, Group 2: ...
# 59821   NCT01244815                    [Placebo, Asenapine 2.5 mg BID]
# 175769  NCT02940886  [Iron Isomaltoside/Ferric Derisomaltose, Iron ...
# 131993  NCT01255592                                 [AZD5069, Placebo]
# 76815   NCT02819518  [Part 2: Pembrolizumab + Chemotherapy, Part 2:...
#
#                                              intervention  \
# 150032                        [GFT505 80mg, GFT505 120mg]
# 206348  [PF-05089771, Placebo, PF-05089771, Placebo, P...
# 130501  [ACC-001 3 μg/ QS-21 50 μg, ACC-001 10 μg/ QS-...
# 48001                                 [Remote Management]
# 30618                      [Sotagliflozin, Sotagliflozin]
# 210754  [Meningococcal Polysaccharide (Serogroups A, C...
# 59821                      [asenapine, Rescue medication]
# 175769           [Iron isomaltoside/ferric derisomaltose]
# 131993                                          [AZD5069]
# 76815   [Pembrolizumab, Nab-paclitaxel, Paclitaxel, Ge...
#
#                                                comparator  \
# 150032                                          [Placebo]
# 206348             [Ibuprofen, Placebo, Placebo, Placebo]
# 130501         [Placebo- Phosphate buffered saline (PBS)]
# 48001                                    [In-Office Care]
# 30618                                           [Placebo]
# 210754  [Meningococcal (Groups A, C, Y and W 135) Olig...
# 59821                        [Placebo to match asenapine]
# 175769                                     [Iron sucrose]
# 131993                                          [Placebo]
# 76815                           [Normale Saline Solution]
#
#                             intervention_group  \
# 150032                             GFT505 80mg
# 206348                                 Placebo
# 130501                          ACC 3 μg+QS-21
# 48001                               Remote Arm
# 30618                     Sotagliflozin 200 mg
# 210754      Group 1: MenACYW Conjugate Vaccine
# 59821                                  Placebo
# 175769  Iron Isomaltoside/Ferric Derisomaltose
# 131993                                 AZD5069
# 76815     Part 2: Pembrolizumab + Chemotherapy
#
#                           comparator_group
# 150032                             Placebo
# 206348                           Ibuprofen
# 130501                             Placebo
# 48001                        In-Office Arm
# 30618                              Placebo
# 210754  Group 1: MenACYW Conjugate Vaccine
# 59821                              Placebo
# 175769                        Iron Sucrose
# 131993                             Placebo
# 76815       Part 2: Placebo + Chemotherapy
# time: 27.6 ms (started: 2023-09-05 08:49:35 +00:00)

# %%
sample = kg_df.sample(10,random_state=220)[['NCT_ID','groups','outcome_title','p_value']]
sample.to_excel(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/sample_effectiveness.xlsx')
sample
# Out:
#              NCT_ID                                             groups  \
# 68525   NCT01995838                      [Lemborexant 2.5 mg, Placebo]
# 91447   NCT00089674                     [Placebo, Denosumab 60 mg Q6M]
# 98329   NCT00348140                              [Placebo, RSG XR 2mg]
# 134858  NCT01360632         [Brexpiprazole (1mg) + ADT, Placebo + ADT]
# 113774  NCT00710554                                 [Sativex, Placebo]
# 124241  NCT01049373  [Lymphdiaral Basistropfen (HDC), Placebo Solut...
# 39612   NCT03400800                              [Inclisiran, Placebo]
# 35500   NCT02912650                        [Placebo, Ibuprofen 250 mg]
# 177120  NCT02954354                           [Baloxavir, Oseltamivir]
# 147362  NCT01795547                       [Aripiprazole, Paliperidone]
#
#                                             outcome_title  p_value
# 68525   Mean Change From Baseline in Sleep Efficiency ...    0.038
# 91447   Number of Participants With Any Fracture Throu...   0.7961
# 98329   Change From Baseline in Alzheimer's Carer's Qu...    0.284
# 134858  Change From Baseline (End of Phase A [Week 8])...   0.0816
# 113774  Change From Baseline in Quality of Life EuroQo...    0.617
# 124241     Change in FFbH-R Between Screening and 2 Weeks   0.0757
# 39612   Percentage Change in LDL-C From Baseline to Da...  <0.0001
# 35500   Pain Intensity Difference on 11-Point Numerica...   <0.001
# 177120  Percentage of Participants Reporting Normal Te...   0.5908
# 147362  Change From Baseline to Week 28 in the 'Interp...     0.07
# time: 339 ms (started: 2023-09-06 08:35:44 +00:00)

# %% [markdown]
# ## case

# %%
infliximab_ade = ade_result_matched_df[ade_result_matched_df['matched_group'].str.lower().str.contains('infliximab')]
infliximab_kg = kg_df[kg_df['intervention_group'].str.lower().str.contains('infliximab')]
infliximab_inter_mesh_rel = inter_group_mesh_rel[inter_group_mesh_rel['intervention_group'].str.lower().str.contains('infliximab')]

print(infliximab_ade.shape,infliximab_ade['NCT_ID'].nunique())
print(infliximab_kg.shape,infliximab_kg['NCT_ID'].nunique())
print(infliximab_inter_mesh_rel.shape)


infliximab_kg.rename(columns={'label':'significance'},inplace=True)
infliximab_ade.rename(columns={'serious/other':'serious_or_other'},inplace=True)

infliximab_ade.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/infliximab_ade.csv')
infliximab_kg.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/infliximab_kg.csv')
infliximab_inter_mesh_rel.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/infliximab_inter_mesh_rel.csv')
# Out:
# (481, 12) 22
# (72, 48) 10
# (38, 3)
# time: 694 ms (started: 2023-08-29 08:11:23 +00:00)
# <ipython-input-33-80b25e628d18>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   infliximab_kg.rename(columns={'label':'significance'},inplace=True)
# <ipython-input-33-80b25e628d18>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   infliximab_ade.rename(columns={'serious/other':'serious_or_other'},inplace=True)

# %%
infliximab_inter_mesh_rel
# Out:
#                                    intervention_group intervention_mesh  \
# 15972                              Infliximab 5 mg/kg        Infliximab
# 17583                                      Infliximab        Infliximab
# 17584                                      Infliximab        Infliximab
# 60868                                      Infliximab        Infliximab
# 60869                                      Infliximab        Infliximab
# 60870                                      Infliximab        Infliximab
# 60871                                      Infliximab        Infliximab
# 96397   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96398   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96399   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96400   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96401   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96402   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 96403   Experimental: Infliximab (Remicade, Revellex)        Infliximab
# 105243                                   A Infliximab        Infliximab
# 105244                                   A Infliximab        Infliximab
# 129560                             Infliximab 5 mg/kg        Infliximab
# 129561                             Infliximab 5 mg/kg        Infliximab
# 210150                           Infliximab / ABP 710        Infliximab
# 210152                           Infliximab / ABP 710        Infliximab
# 210154                           Infliximab / ABP 710        Infliximab
# 210156                           Infliximab / ABP 710        Infliximab
# 210158                           Infliximab / ABP 710        Infliximab
# 210164                           Infliximab / ABP 710        Infliximab
# 210166                           Infliximab / ABP 710        Infliximab
# 210168                           Infliximab / ABP 710        Infliximab
# 210170                           Infliximab / ABP 710        Infliximab
# 210172                           Infliximab / ABP 710        Infliximab
# 210178                           Infliximab / ABP 710        Infliximab
# 210180                           Infliximab / ABP 710        Infliximab
# 210182                           Infliximab / ABP 710        Infliximab
# 210184                           Infliximab / ABP 710        Infliximab
# 210186                           Infliximab / ABP 710        Infliximab
# 210192                           Infliximab / ABP 710        Infliximab
# 210194                           Infliximab / ABP 710        Infliximab
# 210196                           Infliximab / ABP 710        Infliximab
# 210198                           Infliximab / ABP 710        Infliximab
# 210200                           Infliximab / ABP 710        Infliximab
#
#        relation
# 15972      is_a
# 17583      is_a
# 17584      is_a
# 60868      is_a
# 60869      is_a
# 60870      is_a
# 60871      is_a
# 96397      is_a
# 96398      is_a
# 96399      is_a
# 96400      is_a
# 96401      is_a
# 96402      is_a
# 96403      is_a
# 105243     is_a
# 105244     is_a
# 129560     is_a
# 129561     is_a
# 210150     is_a
# 210152     is_a
# 210154     is_a
# 210156     is_a
# 210158     is_a
# 210164     is_a
# 210166     is_a
# 210168     is_a
# 210170     is_a
# 210172     is_a
# 210178     is_a
# 210180     is_a
# 210182     is_a
# 210184     is_a
# 210186     is_a
# 210192     is_a
# 210194     is_a
# 210196     is_a
# 210198     is_a
# 210200     is_a
# time: 12.1 ms (started: 2023-08-29 10:57:36 +00:00)

# %%
kg_df[kg_df['intervention_group'].str.lower().str.contains('infliximab')][['intervention_group','intervention_mesh']].sample(20)
# Out:
#                                    intervention_group  \
# 210170                           Infliximab / ABP 710
# 185477                 PF-06687234 20 mg + Infliximab
# 17584                                      Infliximab
# 210150                           Infliximab / ABP 710
# 210198                           Infliximab / ABP 710
# 86625                           Infliximab + Naproxen
# 96403   Experimental: Infliximab (Remicade, Revellex)
# 210200                           Infliximab / ABP 710
# 2000                                       Infliximab
# 210172                           Infliximab / ABP 710
# 96397   Experimental: Infliximab (Remicade, Revellex)
# 185487                 PF-06687234 20 mg + Infliximab
# 210182                           Infliximab / ABP 710
# 45611        Group I: Placebo Crossover to Infliximab
# 47394           Infliximab + Methotrexate (IFX + MTX)
# 94243        Group I: Placebo Crossover to Infliximab
# 96400   Experimental: Infliximab (Remicade, Revellex)
# 60871                                      Infliximab
# 210158                           Infliximab / ABP 710
# 17583                                      Infliximab
#
#                  intervention_mesh
# 210170                [Infliximab]
# 185477                          []
# 17584                 [Infliximab]
# 210150                [Infliximab]
# 210198                [Infliximab]
# 86625       [Naproxen, Infliximab]
# 96403                 [Infliximab]
# 210200                [Infliximab]
# 2000    [Methotrexate, Infliximab]
# 210172                [Infliximab]
# 96397                 [Infliximab]
# 185487                          []
# 210182                [Infliximab]
# 45611      [Golimumab, Infliximab]
# 47394   [Methotrexate, Infliximab]
# 94243      [Golimumab, Infliximab]
# 96400                 [Infliximab]
# 60871                 [Infliximab]
# 210158                [Infliximab]
# 17583                 [Infliximab]
# time: 104 ms (started: 2023-08-11 12:09:32 +00:00)

# %%
infliximab_ade.groupby('sub_title')['serious/other'].value_counts()
# Out:
# sub_title             serious/other
# ABDOMINAL PAIN        serious          1
# ABORTION INDUCED      serious          1
# ABORTION SPONTANEOUS  serious          1
# ALVEOLITIS            serious          1
# ANAEMIA               serious          1
#                                       ..
# VIRAL INFECTION       serious          1
# Venous stenosis       serious          1
# Vertigo               serious          1
# Viral Infection       serious          2
# Vomiting              serious          1
# Name: serious/other, Length: 344, dtype: int64
# time: 15.5 ms (started: 2023-08-11 06:40:29 +00:00)

# %%
final_df.drop_duplicates().shape
# Out:
# (400, 12)
# time: 7.52 ms (started: 2023-08-10 03:31:00 +00:00)

# %%
final_df.tail(10)
# Out:
#          NCT_ID                   arm_title  \
# 42  NCT00793624                     Placebo
# 43  NCT00790335              A-Intervention
# 44  NCT00303459                     Placebo
# 45  NCT01994889             Tafamidis 80 mg
# 46  NCT01497366                     PEG+RBV
# 47  NCT00330759        Denosumab 120 mg Q4W
# 48  NCT01928394                    PC Arm N
# 49  NCT03366337  Bardoxolone Methyl - ADPKD
# 50  NCT02174627                     Placebo
# 52  NCT01960348       Patisiran (ALN-TTR02)
#
#                              sub_title                            category  \
# 42                         Dehydration  Metabolism and nutrition disorders
# 43                         Cholangitis             Hepatobiliary disorders
# 44                 CHOLECYSTITIS ACUTE             Hepatobiliary disorders
# 45                   Sinus bradycardia                   Cardiac disorders
# 46                           Infection         Infections and infestations
# 47                   Diabetes mellitus  Metabolism and nutrition disorders
# 48  Alanine aminotransferase increased                      Investigations
# 49         Histoplasmosis disseminated         Infections and infestations
# 50                        Sinus arrest                   Cardiac disorders
# 52                   Oedema peripheral                   General disorders
#
#    serious/other  affected  at_risk  events    ratio edge_type matched_group  \
# 42       serious       1.0    225.0     1.0   1/.225    has_ae       Placebo
# 43       serious       1.0    336.0     1.0   1/.336    has_ae           NaN
# 44       serious       1.0    174.0     1.0   1/.174    has_ae       Placebo
# 45       serious       1.0    176.0     1.0   1/.176    has_ae     Tafamidis
# 46       serious       1.0    243.0     1.0   1/.243    has_ae       PEG+RBV
# 47       serious       2.0    878.0     2.0   2/.878    has_ae     Denosumab
# 48       serious       1.0     18.0     1.0    1/.18    has_ae           NaN
# 49       serious       1.0     31.0     1.0    1/.31    has_ae           NaN
# 50       serious       1.0   1377.0     1.0  1/.1377    has_ae       Placebo
# 52       serious       1.0    148.0     1.0   1/.148    has_ae           NaN
#
#     similarity
# 42         NaN
# 43         NaN
# 44         NaN
# 45    0.928323
# 46         NaN
# 47    0.923565
# 48         NaN
# 49         NaN
# 50         NaN
# 52         NaN
# time: 13.2 ms (started: 2023-08-10 03:31:00 +00:00)

# %%
df_ade_sample.tail(10)
# Out:
#              NCT_ID                   arm_title  \
# 227689  NCT00793624                     Placebo
# 228135  NCT00790335              A-Intervention
# 301194  NCT00303459                     Placebo
# 570242  NCT01994889             Tafamidis 80 mg
# 204944  NCT01497366                     PEG+RBV
# 291112  NCT00330759        Denosumab 120 mg Q4W
# 514118  NCT01928394                    PC Arm N
# 165553  NCT03366337  Bardoxolone Methyl - ADPKD
# 615240  NCT02174627                     Placebo
# 551008  NCT01960348       Patisiran (ALN-TTR02)
#
#                                  sub_title  \
# 227689                         Dehydration
# 228135                         Cholangitis
# 301194                 CHOLECYSTITIS ACUTE
# 570242                   Sinus bradycardia
# 204944                           Infection
# 291112                   Diabetes mellitus
# 514118  Alanine aminotransferase increased
# 165553         Histoplasmosis disseminated
# 615240                        Sinus arrest
# 551008                   Oedema peripheral
#
#                                   category serious/other  affected  at_risk  \
# 227689  Metabolism and nutrition disorders       serious       1.0    225.0
# 228135             Hepatobiliary disorders       serious       1.0    336.0
# 301194             Hepatobiliary disorders       serious       1.0    174.0
# 570242                   Cardiac disorders       serious       1.0    176.0
# 204944         Infections and infestations       serious       1.0    243.0
# 291112  Metabolism and nutrition disorders       serious       2.0    878.0
# 514118                      Investigations       serious       1.0     18.0
# 165553         Infections and infestations       serious       1.0     31.0
# 615240                   Cardiac disorders       serious       1.0   1377.0
# 551008                   General disorders       serious       1.0    148.0
#
#         events    ratio edge_type
# 227689     1.0   1/.225    has_ae
# 228135     1.0   1/.336    has_ae
# 301194     1.0   1/.174    has_ae
# 570242     1.0   1/.176    has_ae
# 204944     1.0   1/.243    has_ae
# 291112     2.0   2/.878    has_ae
# 514118     1.0    1/.18    has_ae
# 165553     1.0    1/.31    has_ae
# 615240     1.0  1/.1377    has_ae
# 551008     1.0   1/.148    has_ae
# time: 11.1 ms (started: 2023-08-10 03:31:00 +00:00)

# %%
kg_df[kg_df['NCT_id']=='NCT03366337']
# Out:
# Empty DataFrame
# Columns: [NCT_id, study_type, completion_year, trial_phase, enrollment_num, allocation, Countries, funder_name, funder_type, condition_mesh, intervention_mesh, condition, age, all_inters, intervention_type, intervention, comparator, comparator_type, outcome_id, info, groups, outcome_type, outcome_title, p_value, method, method_desc, ci_percent, ci_n_sides, ci_lower_limit, ci_upper_limit, param_type, param_value, split_p, p_split, label, ci_lower_limit_clean, ci_upper_limit_clean, mesh_terms_mti, mapped_mesh_terms, tree_level_0, intervention_dict, comparator_dict, intervention_group, intervention_value, intervention_similarity, comparator_group, comparator_value, comparator_similarity]
# Index: []
#
# [0 rows x 48 columns]
# time: 22.5 ms (started: 2023-08-10 03:31:37 +00:00)

# %% [markdown]
# # case : Cyclosporine vs kidney 环孢素 vs 肾损伤

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)

ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')
# Out:
# time: 9.79 s (started: 2023-09-17 02:20:27 +00:00)

# %%
cyclosporine_ade = ade_result_matched_df[ade_result_matched_df['matched_group'].str.lower().str.contains('cyclosporine')]
cyclosporine_ade = cyclosporine_ade[cyclosporine_ade['sub_title'].str.lower().str.contains('kidney')|cyclosporine_ade['category'].str.lower().str.contains('renal')]
cyclosporine_kg = kg_df[kg_df['intervention_group'].str.lower().str.contains('cyclosporine')]
cyclosporine_inter_mesh_rel = inter_group_mesh_rel[inter_group_mesh_rel['intervention_group'].str.lower().str.contains('cyclosporine')]

print(cyclosporine_ade.shape,cyclosporine_ade['NCT_ID'].nunique())
print(cyclosporine_kg.shape,cyclosporine_kg['NCT_ID'].nunique())
print(cyclosporine_inter_mesh_rel.shape)


cyclosporine_kg.rename(columns={'label':'significance'},inplace=True)
cyclosporine_ade.rename(columns={'serious/other':'serious_or_other'},inplace=True)

cyclosporine_ade.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/cyclosporine_ade.csv')
cyclosporine_kg.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/cyclosporine_kg.csv')
cyclosporine_inter_mesh_rel.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/cyclosporine_inter_mesh_rel.csv')
# Out:
# (77, 12) 6
# (428, 48) 3
# (0, 3)
# <ipython-input-22-7f32ce1556de>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclosporine_kg.rename(columns={'label':'significance'},inplace=True)
# time: 1.2 s (started: 2023-09-17 07:39:43 +00:00)

# %%
cyclosporine_kg['NCT_ID'].nunique()
# Out:
# 3
# time: 4.21 ms (started: 2023-09-17 02:46:45 +00:00)

# %%
cyclosporine_kg[['NCT_ID','intervention_group','comparator_group','intervention','comparator']].sample(10)
# Out:
#              NCT_ID intervention_group comparator_group  \
# 111049  NCT00658359       Cyclosporine     Cyclosporine
# 111109  NCT00658359       Cyclosporine     Cyclosporine
# 110935  NCT00658359       Cyclosporine     Cyclosporine
# 110901  NCT00658359       Cyclosporine     Cyclosporine
# 110979  NCT00658359       Cyclosporine     Cyclosporine
# 111078  NCT00658359       Cyclosporine     Cyclosporine
# 110840  NCT00658359       Cyclosporine     Cyclosporine
# 110873  NCT00658359       Cyclosporine     Cyclosporine
# 51668   NCT00658359       Cyclosporine     Cyclosporine
# 111053  NCT00658359       Cyclosporine     Cyclosporine
#
#                     intervention      comparator
# 111049  [CP-690,550, CP-690,550]  [Cyclosporine]
# 111109  [CP-690,550, CP-690,550]  [Cyclosporine]
# 110935  [CP-690,550, CP-690,550]  [Cyclosporine]
# 110901  [CP-690,550, CP-690,550]  [Cyclosporine]
# 110979  [CP-690,550, CP-690,550]  [Cyclosporine]
# 111078  [CP-690,550, CP-690,550]  [Cyclosporine]
# 110840  [CP-690,550, CP-690,550]  [Cyclosporine]
# 110873  [CP-690,550, CP-690,550]  [Cyclosporine]
# 51668   [CP-690,550, CP-690,550]  [Cyclosporine]
# 111053  [CP-690,550, CP-690,550]  [Cyclosporine]
# time: 64.6 ms (started: 2023-09-17 08:14:22 +00:00)

# %% [markdown]
# # case:Imipenem

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)

ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')

# %%
imipenem_ade = ade_result_matched_df[ade_result_matched_df['matched_group'].str.lower().str.contains('imipenem')|ade_result_matched_df['matched_group'].str.lower().str.contains('cilastatin')]
imipenem_ade = imipenem_ade[imipenem_ade['sub_title'].str.lower().str.contains('infect')|cyclosporine_ade['category'].str.lower().str.contains('infect')]
imipenem_kg = kg_df[kg_df['intervention_group'].str.lower().str.contains('imipenem')|kg_df['intervention_group'].str.lower().str.contains('cilastatin')]
imipenem_kg = imipenem_kg[imipenem_kg['condition'].astype(str).str.lower().str.contains('infect')]
imipenem_inter_mesh_rel = inter_group_mesh_rel[inter_group_mesh_rel['intervention_group'].str.lower().str.contains('imipenem')|inter_group_mesh_rel['intervention_group'].str.lower().str.contains('cilastatin')]

print(imipenem_ade.shape,imipenem_ade['NCT_ID'].nunique())
print(imipenem_kg.shape,imipenem_kg['NCT_ID'].nunique())
print(imipenem_inter_mesh_rel.shape)


imipenem_kg.rename(columns={'label':'significance'},inplace=True)
imipenem_ade.rename(columns={'serious/other':'serious_or_other'},inplace=True)

imipenem_ade.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/imipenem_ade.csv')
imipenem_kg.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/imipenem_kg.csv')
imipenem_inter_mesh_rel.to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/imipenem_inter_mesh_rel.csv')
# Out:
# <ipython-input-42-dffddd8eac7b>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   imipenem_ade = imipenem_ade[imipenem_ade['sub_title'].str.lower().str.contains('infect')|cyclosporine_ade['category'].str.lower().str.contains('infect')]
# (12, 12) 6
# (27, 48) 3
# (2, 3)
# time: 1.25 s (started: 2023-09-17 08:52:40 +00:00)

# %%
imipenem_inter_mesh_rel
# Out:
#                                        intervention_group intervention_mesh  \
# 186044  Prolonged Infusion. Continuous Piperacillin/Ta...         Meropenem
# 186045  Prolonged Infusion. Continuous Piperacillin/Ta...         Meropenem
#
#        relation
# 186044     is_a
# 186045     is_a
# time: 7.59 ms (started: 2023-09-17 08:34:49 +00:00)

# %%
imipenem_kg[['NCT_ID','intervention_group','condition','significance']]
# Out:
#              NCT_ID                          intervention_group  \
# 20301   NCT01505634  Relebactam 125 mg With Imipenem/Cilastatin
# 20323   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 20324   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 20325   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 20326   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 20327   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 20328   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 20329   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 20330   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 20331   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 63450   NCT01505634  Relebactam 250 mg With Imipenem/Cilastatin
# 63478   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 63479   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 63480   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 72929   NCT02452047     Group 1: Imipenem+Cilastatin/Relebactam
# 72930   NCT02452047     Group 1: Imipenem+Cilastatin/Relebactam
# 72931   NCT02452047     Group 1: Imipenem+Cilastatin/Relebactam
# 88940   NCT01505634  Relebactam 250 mg With Imipenem/Cilastatin
# 88941   NCT01505634  Relebactam 125 mg With Imipenem/Cilastatin
# 88944   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 88945   NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 88946   NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 139237  NCT01505634  Relebactam 250 mg With Imipenem/Cilastatin
# 139238  NCT01505634  Relebactam 125 mg With Imipenem/Cilastatin
# 139347  NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
# 139348  NCT01506271  Relebactam 125 mg With Imipenem/Cilastatin
# 139349  NCT01506271  Relebactam 250 mg With Imipenem/Cilastatin
#
#                                              condition significance
# 20301   ['Urinary Tract Infections', 'Pyelonephritis']     positive
# 20323                   ['Intra-abdominal Infections']     positive
# 20324                   ['Intra-abdominal Infections']     positive
# 20325                   ['Intra-abdominal Infections']     positive
# 20326                   ['Intra-abdominal Infections']     positive
# 20327                   ['Intra-abdominal Infections']     positive
# 20328                   ['Intra-abdominal Infections']     positive
# 20329                   ['Intra-abdominal Infections']     positive
# 20330                   ['Intra-abdominal Infections']     positive
# 20331                   ['Intra-abdominal Infections']     positive
# 63450   ['Urinary Tract Infections', 'Pyelonephritis']     positive
# 63478                   ['Intra-abdominal Infections']     positive
# 63479                   ['Intra-abdominal Infections']     positive
# 63480                   ['Intra-abdominal Infections']     positive
# 72929                         ['Bacterial Infections']     positive
# 72930                         ['Bacterial Infections']     positive
# 72931                         ['Bacterial Infections']     positive
# 88940   ['Urinary Tract Infections', 'Pyelonephritis']     negative
# 88941   ['Urinary Tract Infections', 'Pyelonephritis']     negative
# 88944                   ['Intra-abdominal Infections']     negative
# 88945                   ['Intra-abdominal Infections']     negative
# 88946                   ['Intra-abdominal Infections']     negative
# 139237  ['Urinary Tract Infections', 'Pyelonephritis']     negative
# 139238  ['Urinary Tract Infections', 'Pyelonephritis']     negative
# 139347                  ['Intra-abdominal Infections']     negative
# 139348                  ['Intra-abdominal Infections']     negative
# 139349                  ['Intra-abdominal Infections']     negative
# time: 11.5 ms (started: 2023-09-17 09:45:17 +00:00)

# %%
imipenem_ade[['NCT_ID','arm_title','sub_title','category','serious_or_other','affected','at_risk']]
# Out:
#              NCT_ID                                          arm_title  \
# 77880   NCT00515034              cIAI Treated With Imipenem/Cilastatin
# 100080  NCT02321800                                Imipenem/Cilastatin
# 204912  NCT00589693                                Imipenem-cilastatin
# 204916  NCT00589693                                Imipenem-cilastatin
# 204917  NCT00589693                                Imipenem-cilastatin
# 204918  NCT00589693                                Imipenem-cilastatin
# 204922  NCT00589693                                Imipenem-cilastatin
# 466740  NCT01506271         Relebactam 125 mg With Imipenem/Cilastatin
# 466741  NCT01506271         Relebactam 125 mg With Imipenem/Cilastatin
# 752079  NCT01721408                                Imipenem/Cilastatin
# 789906  NCT02452047            Group 1: Imipenem+Cilastatin/Relebactam
# 789922  NCT02452047  Group 3: Open-Label Imipenem+Cilastatin/Releba...
#
#                                   sub_title                     category  \
# 77880               urinary tract infection  Infections and infestations
# 100080             Device related infection  Infections and infestations
# 204912              Urinary tract infection  Infections and infestations
# 204916             Device related infection  Infections and infestations
# 204917                     Fungal infection  Infections and infestations
# 204918                       Lung infection  Infections and infestations
# 204922        Postoperative wound infection  Infections and infestations
# 466740      Clostridium difficile infection  Infections and infestations
# 466741        Postoperative wound infection  Infections and infestations
# 752079        Postoperative wound infection  Infections and infestations
# 789906                       Lung infection  Infections and infestations
# 789922  Escherichia urinary tract infection  Infections and infestations
#
#        serious_or_other  affected  at_risk
# 77880           serious       1.0     19.0
# 100080          serious       1.0    148.0
# 204912          serious       1.0    112.0
# 204916          serious       1.0    112.0
# 204917          serious       1.0    112.0
# 204918          serious       1.0    112.0
# 204922          serious       1.0    112.0
# 466740          serious       1.0    116.0
# 466741          serious       1.0    116.0
# 752079          serious       2.0    232.0
# 789906          serious       1.0     31.0
# 789922          serious       1.0      3.0
# time: 15.7 ms (started: 2023-09-17 09:53:11 +00:00)

# %%
imipenem_ade[['NCT_ID','arm_title','sub_title','category','serious_or_other','affected','at_risk']].to_csv(f'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/samples/imipenem_ade_for_manu.csv')
# Out:
# time: 11.9 ms (started: 2023-09-17 10:05:44 +00:00)

# %% [markdown]
# # case: infections

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)

ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')

kg_df.rename(columns={'label':'significance'},inplace=True)
ade_result_matched_df.rename(columns={'serious/other':'serious_or_other'},inplace=True)
# Out:
# time: 6 s (started: 2023-09-27 00:20:45 +00:00)

# %%
infection_kg_df = kg_df[kg_df['condition'].astype(str).str.lower().str.contains('infect')]
infection_kg_df['condition_mesh'] = infection_kg_df['condition_mesh'].apply(lambda x:ast.literal_eval(x))
infection_kg_df = infection_kg_df[infection_kg_df['condition_mesh'].str.len()==1]
infection_kg_df['condition_mesh'] = infection_kg_df['condition_mesh'].apply(lambda x:x[0])

infection_ade_df = ade_result_matched_df[ade_result_matched_df['sub_title'].str.lower().str.contains('infect')|ade_result_matched_df['category'].str.lower().str.contains('infect')]
infection_ade_df = infection_ade_df[infection_ade_df['matched_group'].isin(infection_kg_df['intervention_group'].unique())]
# Out:
# <ipython-input-5-cac94ad50a2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   infection_kg_df['condition_mesh'] = infection_kg_df['condition_mesh'].apply(lambda x:ast.literal_eval(x))
# time: 1.46 s (started: 2023-09-27 00:20:51 +00:00)

# %%
infection_ade_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/infection_ade_df.csv')
infection_kg_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/infection_kg_df.csv')
inter_group_mesh_rel.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/inter_group_mesh_rel_0829.csv')
# Out:
# time: 545 ms (started: 2023-09-18 03:09:57 +00:00)

# %%
infection_ade_df['matched_group'].nunique()
# Out:
# 269
# time: 4.59 ms (started: 2023-09-18 05:43:10 +00:00)

# %%
infection_ade_df['matched_group'].value_counts()
# Out:
# Placebo                      11662
# Palivizumab                    214
# Ctrl-6W-6M/043+053 Group       169
# Vancomycin                     166
# E/C/F/TAF                      144
#                              ...
# Standard Course Treatment        1
# Concomitant Group                1
# HIV-uninfected RotaTeq           1
# V920 High-dose Lot               1
# 2% Bisphosphocin Nu-3            1
# Name: matched_group, Length: 269, dtype: int64
# time: 7.32 ms (started: 2023-09-18 05:43:23 +00:00)

# %%
infection_kg_df['condition_mesh'].value_counts()
# Out:
# HIV Infections                            659
# Pneumococcal Infections                   657
# Infections                                326
# Meningococcal Infections                  168
# Peripheral Nervous System Diseases        156
# Respiratory Tract Infections              130
# Streptococcal Infections                  119
# Bacterial Infections                       81
# Influenza, Human                           67
# Communicable Diseases                      55
# Cytomegalovirus Infections                 53
# Urinary Tract Infections                   50
# Hemorrhagic Fever, Ebola                   39
# Rotavirus Infections                       31
# Respiratory Syncytial Virus Infections     21
# COVID-19                                   18
# Zika Virus Infection                       18
# Rabies                                     17
# Glycogen Storage Disease Type II           16
# Candidiasis                                15
# Staphylococcal Infections                  12
# Sexually Transmitted Diseases              12
# Papillomavirus Infections                  11
# Sepsis                                     10
# Wound Infection                             7
# Uveitis                                     7
# Fatigue                                     7
# Papilloma                                   6
# Caliciviridae Infections                    6
# Malaria                                     5
# Coronavirus Infections                      4
# Skin Diseases, Bacterial                    4
# Virus Diseases                              4
# Substance-Related Disorders                 3
# Acquired Immunodeficiency Syndrome          3
# Tuberculosis                                3
# Chikungunya Fever                           3
# Hyperlipidemias                             3
# Impetigo                                    2
# Alcoholism                                  1
# Herpes Zoster                               1
# Name: condition_mesh, dtype: int64
# time: 6.53 ms (started: 2023-09-18 06:06:38 +00:00)

# %%
infection_ade_df['sub_title'].value_counts()
# Out:
# Pneumonia                          803
# Urinary tract infection            372
# Cellulitis                         341
# Sepsis                             335
# Gastroenteritis                    332
#                                   ...
# Vestibuar Neuronitis                 1
# Pumonary tuberculosis                1
# Any Infections and Infestations      1
# Any Infections and infestations      1
# Pneumonia acinetobacter              1
# Name: sub_title, Length: 1732, dtype: int64
# time: 8.92 ms (started: 2023-09-18 06:07:31 +00:00)

# %% [markdown]
# ## by mesh C01

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0807_no_thre.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)
ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')

kg_df.rename(columns={'label':'significance'},inplace=True)
ade_result_matched_df.rename(columns={'serious/other':'serious_or_other'},inplace=True)
# Out:
# time: 2.32 s (started: 2023-09-20 07:56:32 +00:00)

# %% [markdown]
# ### mesh_2021

# %%
mesh_2021 = pd.read_csv(r'/content/drive/MyDrive/PKU/杜老师/AIreport/0929/MeSH_2021.csv').dropna(subset=['TREENUMBER'])
print(mesh_2021.shape)
print(mesh_2021.isnull().sum())
mesh_2021['two_digit'] = mesh_2021['TREENUMBER'].apply(lambda x:[i[:3] for i in x.split(';')])
mesh_2021.sample(5)
# Out:
# (29915, 3)
# UI            0
# NAME          0
# TREENUMBER    0
# dtype: int64
#                UI                           NAME  \
# 17298  D000080871                  Movable Books
# 19919     D046932                      Nodularia
# 28692     D006884  Hydroxybutyrate Dehydrogenase
# 309       D049892                            Mya
# 6893      D004271                    DNA, Fungal
#
#                                         TREENUMBER        two_digit
# 17298                                      V02.535            [V02]
# 19919  B03.280.550;B03.440.475.100.550;B03.585.625  [B03, B03, B03]
# 28692                      D08.811.682.047.820.350            [D08]
# 309                        B01.050.500.644.080.535            [B01]
# 6893                               D13.444.308.300            [D13]
# time: 1.43 s (started: 2023-09-20 07:37:36 +00:00)

# %%
def finder(terms):

  if str(terms)!='nan':
    mapped_list = []
    for i in terms:
      mapped_term = mesh_2021.loc[mesh_2021['NAME']==i]['two_digit'].tolist()
      if len(mapped_term)!=0 :
        mapped_list.append(mapped_term[0])

    return list(set([x for i in mapped_list for x in i ]))
  else:
    return terms

def find_two(df):

  df['three_digit_mesh'] = df['mesh_terms_mti'].apply(finder)
  return df
# Out:
# time: 1.55 ms (started: 2023-09-20 08:07:04 +00:00)

# %%
kg_df = find_two(kg_df)

# %%
kg_df.to_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0920_with_three.pickle')
# Out:
# time: 1.99 s (started: 2023-09-20 08:20:59 +00:00)

# %% [markdown]
# ## lets go

# %%
kg_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/kg_df_0920_with_three.pickle')
kg_df.rename(columns={'NCT_id':'NCT_ID'},inplace=True)
ade_result_matched_df = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ADE/ade_result_matched_df_0809.pickle')
inter_group_mesh_rel = pd.read_pickle(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/inter_group_mesh_rel_0829.pickle')

kg_df.rename(columns={'label':'significance'},inplace=True)
ade_result_matched_df.rename(columns={'serious/other':'serious_or_other'},inplace=True)
# Out:
# time: 11 s (started: 2023-09-30 01:16:42 +00:00)

# %%
test_df = kg_df[kg_df['intervention_mesh'].str.len()==1]
test_df = test_df[test_df['intervention_type'].str.len()==1]
test_df['intervention_mesh'] = test_df['intervention_mesh'].apply(lambda x:x[0])
test_df['intervention_type'] = test_df['intervention_type'].apply(lambda x:x[0])

test_df.rename(columns={'intervention_group':'matched_group'},inplace=True)
test_df[['matched_group','intervention_mesh','intervention_type']].sample(10)
# Out:
# <ipython-input-20-9b31ac438a0c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['intervention_mesh'] = test_df['intervention_mesh'].apply(lambda x:x[0])
# <ipython-input-20-9b31ac438a0c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['intervention_type'] = test_df['intervention_type'].apply(lambda x:x[0])
# <ipython-input-20-9b31ac438a0c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.rename(columns={'intervention_group':'matched_group'},inplace=True)
#                                 matched_group     intervention_mesh  \
# 87659                          Vibegron 75 mg  Tolterodine Tartrate
# 186984                       BI 409306 Pooled             BI 409306
# 111157                   Canagliflozin 300 mg         Canagliflozin
# 216288            LY900010 (Particle Size #2)             Tadalafil
# 39169                         LIK066 50 mg qd         Licogliflozin
# 7007                              Risedronate       Risedronic Acid
# 180392  Treatment B (CHF 718 pMDI 400 µg TDD)        Beclomethasone
# 221883                        Group 1: QIV-HD              Vaccines
# 207598       Part 2: Placebo for MK-8521-T2DM           Liraglutide
# 64573                              GW-1000-02            Nabiximols
#
#        intervention_type
# 87659               Drug
# 186984              Drug
# 111157              Drug
# 216288              Drug
# 39169               Drug
# 7007                Drug
# 180392              Drug
# 221883        Biological
# 207598              Drug
# 64573               Drug
# time: 227 ms (started: 2023-09-30 01:41:24 +00:00)

# %%
test_df.groupby(['intervention_group'])[['intervention_type','intervention_mesh']].value_counts().reset_index()
# Out:
#                     intervention_group intervention_type  \
# 0     0.017% P-321 Ophthalmic Solution              Drug
# 1                      0.03 mg SM04690              Drug
# 2                      0.07 mg SM04690              Drug
# 3        0.1 Milligrams (mg) LY2189265              Drug
# 4      0.10% HL036 Ophthalmic Solution        Biological
# ...                                ...               ...
# 2827                           iOWH032              Drug
# 2828                   iQuit Mindfully        Behavioral
# 2829      incobotulinumtoxinA (Xeomin)              Drug
# 2830             rMenBOMV+ACWY_D Group        Biological
# 2831             rMenBOMV+ACWY_S Group        Biological
#
#              intervention_mesh   0
# 0     Pharmaceutical Solutions   6
# 1                 Lorecivivint  22
# 2                 Lorecivivint  22
# 3                  Dulaglutide   4
# 4     Pharmaceutical Solutions   4
# ...                        ...  ..
# 2827     Anti-Bacterial Agents   9
# 2828                  Nicotine   1
# 2829       incobotulinumtoxinA   2
# 2830                  Vaccines  26
# 2831                  Vaccines   8
#
# [2832 rows x 4 columns]
# time: 49.8 ms (started: 2023-09-30 01:27:18 +00:00)

# %%
ade_result_matched_df
# Out:
#              NCT_ID                   arm_title  \
# 0       NCT01711294             19G Flex Needle
# 1       NCT01711294             19G Flex Needle
# 2       NCT01711294             19G Flex Needle
# 3       NCT01711294             19G Flex Needle
# 4       NCT01711294             19G Flex Needle
# ...             ...                         ...
# 804807  NCT02612428  Standard of Care (Control)
# 804808  NCT02612428  Standard of Care (Control)
# 804809  NCT02612428  Standard of Care (Control)
# 804810  NCT02612428  Standard of Care (Control)
# 804811  NCT02612428  Standard of Care (Control)
#
#                             sub_title  \
# 0          Total, all-cause mortality
# 1       Total, serious adverse events
# 2                  Pancreatitis acute
# 3                     Gastroenteritis
# 4       Endometrial cancer metastatic
# ...                               ...
# 804807  Oesophageal Variceal Ligation
# 804808                    Hypotension
# 804809             Hypovolaemic Shock
# 804810       Orthostatic Hypotenstion
# 804811                          Shock
#
#                                                  category serious_or_other  \
# 0                                                   Total          serious
# 1                                                   Total          serious
# 2                              Gastrointestinal disorders          serious
# 3                             Infections and infestations          serious
# 4       Neoplasms benign, malignant and unspecified (i...          serious
# ...                                                   ...              ...
# 804807                    Surgical and medical procedures          serious
# 804808                                 Vascular disorders          serious
# 804809                                 Vascular disorders          serious
# 804810                                 Vascular disorders          serious
# 804811                                 Vascular disorders          serious
#
#         affected  at_risk  events   ratio edge_type  \
# 0            1.0    121.0     1.0  1/.121    has_ae
# 1            3.0    121.0     3.0  3/.121    has_ae
# 2            1.0    121.0     1.0  1/.121    has_ae
# 3            1.0    121.0     1.0  1/.121    has_ae
# 4            1.0    121.0     1.0  1/.121    has_ae
# ...          ...      ...     ...     ...       ...
# 804807       1.0     75.0     1.0   1/.75    has_ae
# 804808       3.0     75.0     3.0   3/.75    has_ae
# 804809       2.0     75.0     2.0   2/.75    has_ae
# 804810       1.0     75.0     1.0   1/.75    has_ae
# 804811       1.0     75.0     1.0   1/.75    has_ae
#
#                      matched_group  similarity
# 0                  19G Flex Needle         NaN
# 1                  19G Flex Needle         NaN
# 2                  19G Flex Needle         NaN
# 3                  19G Flex Needle         NaN
# 4                  19G Flex Needle         NaN
# ...                            ...         ...
# 804807  Standard of Care (Control)         NaN
# 804808  Standard of Care (Control)         NaN
# 804809  Standard of Care (Control)         NaN
# 804810  Standard of Care (Control)         NaN
# 804811  Standard of Care (Control)         NaN
#
# [803052 rows x 12 columns]
# time: 45.4 ms (started: 2023-09-30 01:17:12 +00:00)

# %%
print(ade_result_matched_df.shape)
# Out:
# (803052, 12)
# time: 641 µs (started: 2023-09-30 01:48:28 +00:00)

# %%
merged_ade = pd.merge(ade_result_matched_df,test_df[['NCT_ID','matched_group','intervention_mesh','intervention_type']].drop_duplicates(),on=['NCT_ID','matched_group'],how='left')
# Out:
# time: 447 ms (started: 2023-09-30 01:58:01 +00:00)

# %%
print(merged_ade.shape)
# Out:
# (803052, 14)
# time: 510 µs (started: 2023-09-30 01:58:02 +00:00)

# %%
merged_ade[merged_ade['intervention_mesh'].notna()]
# Out:
#              NCT_ID                                  arm_title  \
# 186     NCT01716754                           QGE031 High Dose
# 187     NCT01716754                           QGE031 High Dose
# 188     NCT01716754                           QGE031 High Dose
# 189     NCT01716754                           QGE031 High Dose
# 190     NCT01716754                           QGE031 High Dose
# ...             ...                                        ...
# 802691  NCT02613572  Alpha Lipoic Acid (ALA) 1200mg (Phase II)
# 802692  NCT02613572  Alpha Lipoic Acid (ALA) 1200mg (Phase II)
# 802693  NCT02613572  Alpha Lipoic Acid (ALA) 1200mg (Phase II)
# 802694  NCT02613572  Alpha Lipoic Acid (ALA) 1200mg (Phase II)
# 802695  NCT02613572  Alpha Lipoic Acid (ALA) 1200mg (Phase II)
#
#                             sub_title  \
# 186     Total, serious adverse events
# 187           Coronary artery disease
# 188             Drug hypersensitivity
# 189                        Cellulitis
# 190                          Impetigo
# ...                               ...
# 802691       Subarachnoid Haemorrhage
# 802692       Cerebrovascular Accident
# 802693                     Aspiration
# 802694             Pulmonary Embolism
# 802695                     Thrombosis
#
#                                                category serious_or_other  \
# 186                                               Total          serious
# 187                                   Cardiac disorders          serious
# 188                             Immune system disorders          serious
# 189                         Infections and infestations          serious
# 190                         Infections and infestations          serious
# ...                                                 ...              ...
# 802691   Injury, poisoning and procedural complications          serious
# 802692                         Nervous system disorders          serious
# 802693  Respiratory, thoracic and mediastinal disorders          serious
# 802694  Respiratory, thoracic and mediastinal disorders          serious
# 802695                               Vascular disorders          serious
#
#         affected  at_risk  events   ratio edge_type  \
# 186          9.0    199.0     9.0  9/.199    has_ae
# 187          1.0    199.0     1.0  1/.199    has_ae
# 188          1.0    199.0     1.0  1/.199    has_ae
# 189          1.0    199.0     1.0  1/.199    has_ae
# 190          1.0    199.0     1.0  1/.199    has_ae
# ...          ...      ...     ...     ...       ...
# 802691       1.0     26.0     1.0   1/.26    has_ae
# 802692       1.0     26.0     1.0   1/.26    has_ae
# 802693       1.0     26.0     1.0   1/.26    has_ae
# 802694       1.0     26.0     1.0   1/.26    has_ae
# 802695       1.0     26.0     1.0   1/.26    has_ae
#
#                          matched_group  similarity intervention_mesh  \
# 186                  QGE031 240 mg q2w    0.890557        Omalizumab
# 187                  QGE031 240 mg q2w    0.890557        Omalizumab
# 188                  QGE031 240 mg q2w    0.890557        Omalizumab
# 189                  QGE031 240 mg q2w    0.890557        Omalizumab
# 190                  QGE031 240 mg q2w    0.890557        Omalizumab
# ...                                ...         ...               ...
# 802691  Alpha Lipoic Acid (ALA) 1200mg    0.979870     Thioctic Acid
# 802692  Alpha Lipoic Acid (ALA) 1200mg    0.979870     Thioctic Acid
# 802693  Alpha Lipoic Acid (ALA) 1200mg    0.979870     Thioctic Acid
# 802694  Alpha Lipoic Acid (ALA) 1200mg    0.979870     Thioctic Acid
# 802695  Alpha Lipoic Acid (ALA) 1200mg    0.979870     Thioctic Acid
#
#        intervention_type
# 186                 Drug
# 187                 Drug
# 188                 Drug
# 189                 Drug
# 190                 Drug
# ...                  ...
# 802691              Drug
# 802692              Drug
# 802693              Drug
# 802694              Drug
# 802695              Drug
#
# [92162 rows x 14 columns]
# time: 268 ms (started: 2023-09-30 01:58:06 +00:00)

# %%
merged_ade.groupby(['intervention_mesh','intervention_type'])[['affected']].sum().reset_index().sort_values(by=['affected'],ascending=False).head(10)
# Out:
#     intervention_mesh intervention_type  affected
# 166  Darbepoetin alfa              Drug   16968.0
# 640         Vorapaxar              Drug   14575.0
# 163     Dapagliflozin              Drug   13267.0
# 174         Denosumab              Drug   11175.0
# 165        Darapladib              Drug   10860.0
# 214      Epoetin Alfa              Drug   10270.0
# 619          Vaccines        Biological    9967.0
# 592        Ticagrelor              Drug    9845.0
# 232        Evolocumab        Biological    9317.0
# 360       Liraglutide              Drug    9085.0
# time: 119 ms (started: 2023-09-30 02:39:13 +00:00)

# %%
merged_ade.groupby(['matched_group'])[['affected']].sum().reset_index().sort_values(by=['affected'],ascending=False).head(20)
# Out:
#                          matched_group  affected
# 12788                          Placebo  387640.0
# 4736                           Control   39342.0
# 17484        Warfarin/Placebo Edoxaban   32282.0
# 8735                      Intervention   30495.0
# 13114              Placebo Anacetrapib   28113.0
# 1879                       Anacetrapib   27619.0
# 5290                  Darbepoetin Alfa   24910.0
# 17481                         Warfarin   24322.0
# 4915      Current BLS Training Program   24270.0
# 16383                 Ticagrelor 60 mg   22793.0
# 6637             Ezetimibe/Simvastatin   21293.0
# 16267           Telmisartan (ONTARGET)   20662.0
# 14145              Ramipril (ONTARGET)   20226.0
# 16277  Telmisartan/Ramipril (ONTARGET)   19787.0
# 8861                        Ivabradine   18876.0
# 17206                        Valsartan   18809.0
# 2742                           Aspirin   18699.0
# 11124                          Omega-3   17715.0
# 13116                  Placebo Aspirin   17573.0
# 13222                  Placebo Omega-3   17493.0
# time: 105 ms (started: 2023-09-30 02:27:40 +00:00)

# %%
merged_ade.groupby('category')['affected'].sum().reset_index().sort_values(by=['affected'],ascending=False).head(11)
# Out:
#                                              category   affected
# 26                                              Total  1485514.0
# 10                        Infections and infestations   294602.0
# 1                                   Cardiac disorders   286035.0
# 7                                   General disorders   195018.0
# 6                          Gastrointestinal disorders   168440.0
# 22    Respiratory, thoracic and mediastinal disorders   147184.0
# 15  Neoplasms benign, malignant and unspecified (i...   132976.0
# 16                           Nervous system disorders   129127.0
# 11     Injury, poisoning and procedural complications   104784.0
# 27                                 Vascular disorders    93766.0
# 0                Blood and lymphatic system disorders    78164.0
# time: 80.5 ms (started: 2023-09-30 02:07:47 +00:00)

# %%
merged_ade[merged_ade['category']!='Total']['affected'].sum()
# Out:
# 2106063.0
# time: 189 ms (started: 2023-09-30 02:21:56 +00:00)

# %%
merged_ade[merged_ade['category']!='Total'].drop_duplicates(subset=['NCT_ID'])['at_risk'].sum()
# Out:
# 3538554.0
# time: 199 ms (started: 2023-09-30 02:24:16 +00:00)

# %%
ade_result_matched_df.columns
# Out:
# Index(['NCT_ID', 'arm_title', 'sub_title', 'category', 'serious_or_other',
#        'affected', 'at_risk', 'events', 'ratio', 'edge_type', 'matched_group',
#        'similarity'],
#       dtype='object')
# time: 4.61 ms (started: 2023-09-28 03:02:06 +00:00)

# %%
kg_df[['NCT_ID','intervention_group','intervention_value','intervention_mesh']].to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/efficacy_groups_0928.csv')
# Out:
# time: 540 ms (started: 2023-09-28 03:00:43 +00:00)

# %%
kg_df[['NCT_ID','intervention_group','intervention_value','intervention_mesh']].sample(20)
# Out:
#              NCT_ID          intervention_group intervention_value  \
# 102280  NCT00190749                  Olanzapine               Drug
# 98328   NCT00348140                  RSG XR 8mg               Drug
# 123858  NCT01035346            Ibuprofen Sodium               Drug
# 130438  NCT01227265            Preladenant 2 mg               Drug
# 102881  NCT00420238                  Etanercept               Drug
# 1853    NCT00212134    Aphakic Intraocular Lens             Device
# 93575   NCT00168818            Dabigatran 150mg               Drug
# 133064  NCT01301456  Stage 2: PF-04856883 12 mg         Biological
# 99528   NCT00385671     Gabapentin + Duloxetine               Drug
# 18712   NCT01380093                    Morphine               Drug
# 98999   NCT00361257                 Minocycline               Drug
# 63782   NCT01543685            Celecoxib 200 mg               Drug
# 119396  NCT00895895            SAM-531 (5.0 mg)               Drug
# 186880  NCT03058692                M-001 + IIV4         Biological
# 2332    NCT00286442       Alogliptin 12.5 mg QD               Drug
# 65568   NCT01441635            Cohort 4 Placebo               Drug
# 147452  NCT01794923            Placebo Combined               Drug
# 90699   NCT00048061          Ibandronate 100 mg               Drug
# 38809   NCT03255382                Risankizumab               Drug
# 141342  NCT01578850                  Etanercept               Drug
#
#                                         intervention_mesh
# 102280                          [Olanzapine, Risperidone]
# 98328                                     [Rosiglitazone]
# 123858                                        [Ibuprofen]
# 130438                                                 []
# 102881                                       [Etanercept]
# 1853                                         [Dipivefrin]
# 93575                            [Enoxaparin, Dabigatran]
# 133064                                                 []
# 99528   [Pregabalin, Gabapentin, Duloxetine Hydrochlor...
# 18712                              [Naltrexone, Morphine]
# 98999                         [Minocycline, Tetracycline]
# 63782                           [Celecoxib, Indomethacin]
# 119396                                        [Donepezil]
# 186880                                         [Vaccines]
# 2332                              [Metformin, Alogliptin]
# 65568   [Estradiol 17 beta-cypionate, Estradiol 3-benz...
# 147452                                                 []
# 90699               [Vitamin D, Ibandronic Acid, Calcium]
# 38809                                 [Dimethyl Fumarate]
# 141342                                       [Etanercept]
# time: 35.6 ms (started: 2023-09-28 03:05:51 +00:00)

# %%
ade_result_matched_df[['NCT_ID','arm_title','matched_group']].to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/ade_groups_0928.csv')
# Out:
# time: 2.57 s (started: 2023-09-28 02:59:48 +00:00)

# %%
infection_outcome_df = kg_df[kg_df['three_digit_mesh'].astype(str).str.contains('C01')|kg_df['outcome_title'].str.lower().str.contains('infect')]

infection_ade_df = ade_result_matched_df[ade_result_matched_df['sub_title'].str.lower().str.contains('infect')|ade_result_matched_df['category'].str.lower().str.contains('infect')]
infection_ade_df = infection_ade_df[infection_ade_df['matched_group'].isin(infection_outcome_df['intervention_group'].unique())]

infection_outcome_df = infection_outcome_df[infection_outcome_df['intervention_group'].isin(infection_ade_df['matched_group'].unique())]
pos_infection_outcome_df = infection_outcome_df[infection_outcome_df['significance']=='positive']
neg_infection_outcome_df = infection_outcome_df[infection_outcome_df['significance']=='negative']

infection_ade_df = infection_ade_df[infection_ade_df['matched_group'].isin(pos_infection_outcome_df['intervention_group'].unique())]

print(infection_outcome_df.shape,infection_outcome_df['NCT_ID'].nunique())
print(infection_ade_df.shape,infection_ade_df['NCT_ID'].nunique())
print(pos_infection_outcome_df.shape,pos_infection_outcome_df['NCT_ID'].nunique())
print(neg_infection_outcome_df.shape,neg_infection_outcome_df['NCT_ID'].nunique())
# Out:
# (1140, 49) 232
# (14814, 12) 1533
# (406, 49) 129
# (734, 49) 177
# time: 1.39 s (started: 2023-09-27 00:36:15 +00:00)

# %%
print(pos_infection_outcome_df['intervention_group'].nunique())
unique_inters = set([item.lower() for sublist in pos_infection_outcome_df['intervention'].tolist() for item in sublist])
unique_inter_mesh = set([item.lower() for sublist in pos_infection_outcome_df['intervention_mesh'].tolist() for item in sublist])

unique_ade_groups = list(set(infection_ade_df['matched_group'].tolist()))
print(len(unique_ade_groups))
print(len(unique_inters))
print(len(unique_inter_mesh))
# Out:
# 139
# 139
# 160
# 108
# time: 4.14 ms (started: 2023-09-27 01:16:08 +00:00)

# %%
print(unique_inter_mesh)
# Out:
# {'taurolidine', 'peginterferon alfa-2b', 'metronidazole', 'chloroquine', 'paclitaxel', 'acetaminophen', 'valganciclovir', 'lamivudine', 'efavirenz, emtricitabine, tenofovir disoproxil fumarate drug combination', 'terbinafine', 'loratadine', 'vincristine', 'adapalene', 'sulfadoxine', 'everolimus', 'antibodies', 'interferon alpha-2', 'ribavirin', 'trimethoprim, sulfamethoxazole drug combination', 'rho(d) immune globulin', 'immunoglobulins', 'methylprednisolone hemisuccinate', 'thrombin', 'peginterferon alfa-2a', 'darunavir', 'mycophenolic acid', 'alemtuzumab', 'diphenhydramine', 'nevirapine', 'tenofovir', 'cyclosporine', 'infliximab', 'cetuximab', 'cyclosporins', 'sirolimus', 'cobicistat', 'promethazine', 'gamma-globulins', 'trimethoprim', 'mometasone furoate', 'tofacitinib', 'emtricitabine, tenofovir disoproxil fumarate drug combination', 'thymoglobulin', 'maribavir', 'carboplatin', 'bamlanivimab', 'basiliximab', 'pharmaceutical solutions', 'gelatin sponge, absorbable', 'heparin', 'atazanavir sulfate', 'azelaic acid', 'fanasil, pyrimethamine drug combination', 'calcium heparin', 'clindamycin', 'tazarotene', 'vaccines', 'posaconazole', 'interferons', 'olopatadine hydrochloride', 'heptavalent pneumococcal conjugate vaccine', 'ceftriaxone', 'ivermectin', 'simeprevir', 'rilpivirine', 'clotrimazole', 'clindamycin phosphate', 'ganciclovir', 'sulfamethoxazole', 'oseltamivir', 'abacavir', 'raltegravir potassium', 'miconazole', 'mitogens', 'adalimumab', 'amoxicillin', 'tacrolimus', 'nicotinic acids', 'antibodies, monoclonal', 'epinephrine', 'interferon-alpha', 'remdesivir', 'pyrimethamine', 'cobicistat mixture with darunavir', 'camostat', 'ziprasidone', 'efavirenz', 'immunoglobulins, intravenous', 'artemether, lumefantrine drug combination', 'adefovir dipivoxil', 'gabexate', 'clindamycin palmitate', 'letermovir', 'methylprednisolone', 'ganciclovir triphosphate', 'emtricitabine tenofovir alafenamide', 'ophthalmic solutions', 'zidovudine', 'lamivudine, zidovudine drug combination', 'prednisone', 'emtricitabine', 'amodiaquine', 'benzoyl peroxide', 'azithromycin', 'etoposide', 'antilymphocyte serum', 'bleomycin', 'dideoxynucleosides'}
# time: 521 µs (started: 2023-09-27 01:17:23 +00:00)

# %%
print(set(unique_ade_groups))
# Out:
# {'Vaniprevir 24 Week Arm', 'Rabipur Group', '7vPnC After Infant Series Dose 3', 'MK-3415 + SOC', 'Nevirapine QD+BID', 'Vaccine', 'V710 60 µg', 'CD24Fc', 'Enhanced Treatment', 'Priorix-Tetra Group', 'CCI Vaccine', 'Group D: TDV Lyophilized', 'Control', 'HIV+/Cervarix Group', 'rhNGF 20 µg/ml', 'Telaprevir 24 Week+Peg-IFN-alfa-2a,RBV 48 Week', 'V419', 'Placebo + INFANRIX Hexa', 'QIVc (≥4 to <18 Years)', 'Baricitinib + SOC', 'ADV-TDF', 'Ziprasidone', 'Reltecimod (AB103) 0.5 mg/kg', 'Cohort 1-Engerix-B/Prevnar-Hiberix Group', 'Arm 1: Metronidazole Plus Miconazole', 'Neutrolin Arm', 'SB213503 Lot 1 + M-M-R Group', 'Azithromycin', 'DTG + RPV', 'Twinrix Group', 'IVV Vaccine', 'QIVc (≥18 Years)', '7vPnC After the Infant Series', 'ABC/ DTG/ 3TC', 'Immediate Introduction of Everolimus', 'Baloxavir Marboxil', 'PTX+ART', 'RotaTeq™', '4200mg Bamlanivimab', 'MMR Group', 'DTaP (Catch-up 7vPnC)', 'CAB LA+RPV LA (Q4W)', 'Placebo - Asia', 'Immediate ART', 'Telaprevir 12 Week+Peg-IFN-alfa-2a,RBV 48 Week', 'Letermovir', 'Cyclosporine', 'Bimekizumab (PPS)', 'Maribavir 400 mg', 'V501', 'Investigational Device', 'Oral Care With Influenza and Pneumococcal Vaccines', 'MK-6072 + SOC', 'Placebo for 24 Weeks', 'TMC435 150mg 12Wks PR24/48', 'Cohort 2', 'Td Adsorbed Vaccine', 'Baloxavir', 'Pneumosil', 'CT-P59 40 mg/kg Group (Part 2)', 'Test', 'Delafloxacin', 'Zoster-022 GSK1437173A 70-79YOA Group', 'Group 1: QIV-HD', 'Phase 3: 700 mg Bamlanivimab + 1400 mg Etesevimab', 'Cohort 3', 'Azithromycin + Chloroquine', 'Maribavir 100 mg BID', 'Camostat Mesilate', '7vPnC After 2-Dose Infant Series', 'V260 With Staggered or Concomitant EPI', 'Anaferon for Children', 'M72AS01 Group', 'Double-Blind Period - Vicriviroc 20 mg Plus an ART Regimen', 'MEDI8897 50 mg', 'MK-8237', 'TIV (Elderly)', 'Peginterferon Alfa-2a + Ribavirin', 'Clinically Driven Monitoring (CDM)', 'Telaprevir 12 Week +Peg-IFN-alfa-2a,RBV 24 Week', 'Raltegravir 800 mg q.d.', 'V419 Lots A, B, and C Combined', 'MK-3415A + SOC', 'Combined Patients Receiving 74 Gy RT', 'SYN-004', 'Nevirapine', 'Cohort 3 (Placebo, 2-5 Yrs)', 'Camostat Mesylate', 'Telaprevir 8 Week, PBO 4 Week+Peg-IFN-alfa-2a, RBV 24/48 Week', 'DRV/COBI+ FTC/TDF (Control) (Baseline to Switch)', 'TDV Lot 3', 'qHPV Vaccine in Base Study', 'Telaprevir 12 Week+Peg-IFN-alfa-2a,RBV 24 Week', 'Double-Blind Period - Vicriviroc 30 mg Plus an ART Regimen', 'MVA-NP+M1 Group', 'Maternal Chloroquine Prophylaxis', 'FluLaval™ Quadrivalent Group', '4_rhNGF10_Phase 2_treatment', 'V114', 'High-Dose Quadrivalent Influenza Vaccine (QIV-HD)', 'GSK1437173A Group', 'PR5I', 'Stopped Cotrimoxazole Prophylaxis', 'GSK1437173A Overall Ages Group', 'AZD7442', 'Telaprevir 24 Week+Peg-IFN-alfa-2a 24 Week', 'Test Product', 'TOTAL 2-sites, TRC', 'Cohort 1', 'Arm A: hIVIG', 'Posaconazole 100 mg QD for 24 Weeks', 'Remdesivir', 'Menjugate Comparator [6-12W] Group', 'HIV-/Cervarix Group', 'Vaniprevir 12 Week Arm', 'Participants Who Received DTG/3TC FDC', '4-sites, 1-week WITH HRIG', 'Daclatasvir, 60 mg, 12-Week Cohort', 'Intervention', '13vPnC', 'Arm B: ZDV+ABC+3TC+NNRTI->ABC+3TC+NNRTI Maintenance', 'VeroRab Comparator [5-17M] Group', 'Group D', 'PEG 1.0 mcg/kg Weekly (QW) * 24 Weeks', 'Cohort 3 eTIV (3-8 Years)', 'Sotrovimab (500 mg IV)', 'Filgotinib', 'rMenB All', 'Azelaic Acid Foam, 15% (BAY39-6251)', 'QIV-HD', 'Placebo', 'TIV (3-8 Years)', 'Phase 2: 2800 mg Bamlanivimab + 2800 mg Etesevimab', 'TDV Lot 2', '13vPnC After Toddler Dose', 'AZD1222', 'Telaprevir 12 Week+Peg-IFN-alfa-2a, RBV 24/48 Week', 'Agriflu', 'Period 2: Tacrolimus'}
# time: 763 µs (started: 2023-09-27 01:27:02 +00:00)

# %%
infection_ade_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/infection_ade_df.csv')
infection_outcome_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/infection_kg_df.csv')
pos_infection_outcome_df.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/pos_infection_outcome_df.csv')

inter_group_mesh_rel.to_csv(r'/content/drive/MyDrive/PKU/杜老师/data/ct.gov/22-12-25/KG/inter_group_mesh_rel_0829.csv')
# Out:
# time: 376 ms (started: 2023-09-27 00:41:03 +00:00)

# %%
print(infection_ade_df.columns)
infection_outcome_df.columns
# Out:
# Index(['NCT_ID', 'arm_title', 'sub_title', 'category', 'serious_or_other',
#        'affected', 'at_risk', 'events', 'ratio', 'edge_type', 'matched_group',
#        'similarity'],
#       dtype='object')
# Index(['NCT_ID', 'study_type', 'completion_year', 'trial_phase',
#        'enrollment_num', 'allocation', 'Countries', 'funder_name',
#        'funder_type', 'condition_mesh', 'intervention_mesh', 'condition',
#        'age', 'all_inters', 'intervention_type', 'intervention', 'comparator',
#        'comparator_type', 'outcome_id', 'info', 'groups', 'outcome_type',
#        'outcome_title', 'p_value', 'method', 'method_desc', 'ci_percent',
#        'ci_n_sides', 'ci_lower_limit', 'ci_upper_limit', 'param_type',
#        'param_value', 'split_p', 'p_split', 'significance',
#        'ci_lower_limit_clean', 'ci_upper_limit_clean', 'mesh_terms_mti',
#        'mapped_mesh_terms', 'tree_level_0', 'intervention_dict',
#        'comparator_dict', 'intervention_group', 'intervention_value',
#        'intervention_similarity', 'comparator_group', 'comparator_value',
#        'comparator_similarity', 'three_digit_mesh'],
#       dtype='object')
# time: 6.42 ms (started: 2023-09-27 00:28:10 +00:00)

# %%
pd.merge(infection_ade_df[['arm_title','sub_title']].rename(columns={'arm_title':'intervention_group'}),infection_outcome_df[['intervention_group','outcome_title','significance']],on='intervention_group',how='inner').sample(20)
# Out:
#                                intervention_group  \
# 67653                                Cyclosporine
# 76600  Telaprevir 24 Week+Peg-IFN-alfa-2a 24 Week
# 35989                                     Placebo
# 17985                                     Placebo
# 53343                                     Placebo
# 41326                                     Placebo
# 35267                                     Placebo
# 30183                                     Placebo
# 21870                                     Placebo
# 63411                                     Control
# 35382                                     Placebo
# 47059                                     Placebo
# 63968                                     Control
# 41083                                     Placebo
# 66637                                Cyclosporine
# 757                                       Placebo
# 1761                                      Placebo
# 74024                                        V114
# 9677                                      Placebo
# 25955                                     Placebo
#
#                                  sub_title  \
# 67653                Necrotising fasciitis
# 76600                      Gastroenteritis
# 35989                        Infected cyst
# 17985                  INFECTED SKIN ULCER
# 53343                              Abscess
# 41326                               Sepsis
# 35267                Soft tissue infection
# 30183       Wound infection staphylococcal
# 21870                      Pneumonia viral
# 63411                     Pulmonary sepsis
# 35382                      Wound infection
# 47059                        Ear infection
# 63968    Upper respiratory tract infection
# 41083                  Enterobacter sepsis
# 66637                          Tonsillitis
# 757                    Enterococcal sepsis
# 1761                    Escherichia sepsis
# 74024  Escherichia urinary tract infection
# 9677                    COVID-19 pneumonia
# 25955                            SINUSITIS
#
#                                            outcome_title significance
# 67653  Kaplan-Meier Analysis of Percentage of Partici...     negative
# 76600  Percentage of Subjects With Undetectable Plasm...     positive
# 35989  The Change From Baseline in Rhinitis Symptom S...     negative
# 17985  The Change From Baseline in Rhinitis Medicatio...     negative
# 53343  The Change From Baseline in Rhinitis Medicatio...     negative
# 41326  Mean of the Sum of 5 Single Local Common Cold ...     negative
# 35267  Number of Participants With Active COVID-19 Di...     negative
# 30183  The Change From Baseline in Rhinitis Medicatio...     negative
# 21870  Incidence of Confirmed Herpes Zoster (HZ) Case...     positive
# 63411                                             Sepsis     negative
# 35382  Incidence of Confirmed Herpes Zoster (HZ) Case...     positive
# 47059  The Change From Baseline in Rhinitis Symptom S...     negative
# 63968  Percent of Participants With Impaired Wound He...     negative
# 41083  The Change From Baseline in Rhinitis Symptom S...     negative
# 66637  Kaplan-Meier Analysis of Percentage of Partici...     negative
# 757    The Change From Baseline in Rhinitis Symptom S...     negative
# 1761   The Change From Baseline in Rhinitis Medicatio...     negative
# 74024  Percentage of Participants Meeting Response Ra...     positive
# 9677   Number of Participants With Active COVID-19 Di...     negative
# 25955  Number of Participants With Active COVID-19 Di...     negative
# time: 32.8 ms (started: 2023-09-27 00:29:36 +00:00)
